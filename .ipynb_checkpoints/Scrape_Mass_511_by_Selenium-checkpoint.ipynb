# %%
# the selenium part is took from the below link. it is helpful to understand what you need for scraping by Selenium.
# https://medium.freecodecamp.org/better-web-scraping-in-python-with-selenium-beautiful-soup-and-pandas-d6390592e251

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import pandas as pd
import os

# %%
import time
import requests

url = "https://mass511.com/"
res=requests.get(url)
res.status_code
# Out:
# 200

# %%
# # enter origin destination points
# origin=input('enter the origin: ')
# # Medford High School, Winthrop Street, Medford, MA, USA

# %%
# destination=input('enter destination: ')
# # Medford City Hall, George P Hassett Drive, Medford, MA, USA

# %% [markdown]
# ## 1- MANUAL CHECK:

# %% [markdown]
# ### entering the origins&destinations to website

# %%
# for manual check if code runs:
origin='42.436659, -71.090072'
destination='42.411050, -71.092265'

# %%
# this cell is took from the abovementioned link:
# open the webpage by pyhton code!

driver = webdriver.Chrome(executable_path='./chromedriver')
driver.implicitly_wait(30)
driver.get(url)

# %%
python_button = driver.find_element_by_id('startLocationText') # entering origin point to box A
python_button.send_keys(origin)

python_button2 = driver.find_element_by_id('endLocationText') # entering  destination point to box B
python_button2.send_keys(destination)

python_button3=driver.find_element_by_id('generateRouteBtn') # clicking the 'Drive' button and open 1st Route.
python_button3.click()

# %%
python_button4=driver.find_element_by_id('clearRouteBtn') # clear the A and B Boxes for the next query!
python_button4.click()

# %%
driver.quit()

# %% [markdown]
# ## 2- ORIGIN & DESTINATIONS:

# %%
x_y=pd.read_csv('./routes_with_zones.csv')
data = x_y[x_y.Time == "8:30"]
data.head(2)
# Out:
#    Unnamed: 0  osmid_start    x_start    y_start  start_zone  osmid_end  \
# 0           0     66450694 -71.090072  42.436659           1   66449255
# 3           3     66436104 -71.088950  42.439999           1   66445131
#
#        x_end      y_end  end_zone  Time
# 0 -71.092265  42.411050         2  8:30
# 3 -71.090880  42.411045         2  8:30

# %%
new_cols={'x_start':'y_start','y_start':'x_start','x_end':'y_end','y_end':'x_end'}

data.rename(columns=new_cols,inplace=True)
data.head(2)
# Out:
#    Unnamed: 0  osmid_start    y_start    x_start  start_zone  osmid_end  \
# 0           0     66450694 -71.090072  42.436659           1   66449255
# 3           3     66436104 -71.088950  42.439999           1   66445131
#
#        y_end      x_end  end_zone  Time
# 0 -71.092265  42.411050         2  8:30
# 3 -71.090880  42.411045         2  8:30

# %%
data['origin'] = data.apply(lambda row: str(row['x_start']) +', '+ str(row['y_start']), axis=1)
data['destination'] = data.apply(lambda row: str(row['x_end']) +', '+ str(row['y_end']), axis=1)
# Out:
# /anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data=data[:3]
data.tail()
# Out:
#    Unnamed: 0  osmid_start    y_start    x_start  start_zone   osmid_end  \
# 0           0     66450694 -71.090072  42.436659           1    66449255
# 3           3     66436104 -71.088950  42.439999           1    66445131
# 6           6     66483089 -71.094324  42.430675           1  3191029804
#
#        y_end      x_end  end_zone  Time  \
# 0 -71.092265  42.411050         2  8:30
# 3 -71.090880  42.411045         2  8:30
# 6 -71.094565  42.406251         2  8:30
#
#                                    origin                     destination
# 0  42.436659000000006, -71.09007199999999            42.41105, -71.092265
# 3                 42.4399985, -71.0889505  42.41104489999999, -71.0908802
# 6                 42.4306754, -71.0943239  42.4062507, -71.09456479999999

# %%
data.shape
# Out:
# (3, 12)

# %% [markdown]
# ## 3- SCAPE BY LOOP:

# %%
cengiz = []
counter=0
driver = webdriver.Chrome(executable_path='./chromedriver')
driver.implicitly_wait(23)
driver.get(url)
soup=BeautifulSoup(driver.page_source, 'lxml')

for i in data.index:
    
    try:
        enter_A_button = driver.find_element_by_id('startLocationText') # entering origin point to box A
        enter_B_button = driver.find_element_by_id('endLocationText') # entering  destination point to box B
        drive_button =driver.find_element_by_id('generateRouteBtn') # clicking the 'Drive' button and open 1st Route.
        clear_button =driver.find_element_by_id('clearRouteBtn') # clear the A and B Boxes for the next query!

        origin=data['origin'][i] # takes the x,y coordinates of the i^th row of the 'origin' column
        destination=data['destination'][i] # takes the x,y coordinates of the i^th row of the 'destination' column 

        enter_A_button.send_keys(origin)
        enter_B_button.send_keys(destination)
        drive_button.click()
        time.sleep(6) # wait time for each query

        driver.implicitly_wait(1) # wait time after clicking the button

        soup=BeautifulSoup(driver.page_source, 'lxml')
        for j in range(2): # there are 2 Routes where maximum possibilites. 'j' is running for routes
            
            if j==0: # 1st Route loop
                try:
                    loc_1=soup.find('div',{'id':'routeTab-1'}) # the location where keeps the all required data for Route 1
                    route1 = {}
                    key = 0 # create keys for 'from to where','time' and 'distance' in the nested dictionary 
                    cengiz.append(route1)
                    for k in loc_1.find_all('span'): # scrape for 'from to where', 'time' and 'distance columns'
                        route1[key]=k.text.split("\n")[0] # if you remove [0] it works but format will change
                        key +=1

                        loc_1_a=loc_1.find('ul',{'class':'list-group'}) #the location where keeps the all breakdown directions(legs)
                        direction={}
                        key2=0 # create kesy for all legs in the 'direction' dictionary
                        for l in loc_1_a: # scrape all given directions: Bethany did this part for me!
                            direct = str(l.br.previous_sibling).strip()
                            direct=direct.lstrip('<b>').rstrip('</br>')
                            direction[key2]=direct
                            key2+=1

                        route1['direction']=direction
                        route1['route']='Route 1'
                        route1['x_start']=data['x_start'][i]
                        route1['y_start']=data['y_start'][i]
                        route1['x_end']=data['x_end'][i]
                        route1['y_end']=data['y_end'][i]
                        route1['origin']=data['origin'][i]
                        route1['destination']=data['destination'][i]
                        route1['start_zone']=data['start_zone'][i]
                        route1['end_zone']=data['end_zone'][i]
                except:
                    pass

                
            elif j==1:# 2nd Route loop
                try:
                    loc_2=soup.find('div',{'id':'routeTab-2'}) # the location where keeps the all required data for Route 2
                    route2 = {}
                    key = 0
                    cengiz.append(route2)
                    for m in loc_2.find_all('span'):
                        route2[key]=m.text.split("\n")[0] # if you remove [0] it works but format will change
                        key +=1

                        loc_2_a=loc_2.find('ul',{'class':'list-group'})
                        direction={}
                        key2=0
                        for n in loc_2_a:
                            direct = str(n.br.previous_sibling).strip()
                            direct=direct.lstrip('<b>').rstrip('</br>')
                            direction[key2]=direct
                            key2+=1

                        route2['direction']=direction
                        route2['route']='Route 2'
                        route2['x_start']=data['x_start'][i]
                        route2['y_start']=data['y_start'][i]
                        route2['x_end']=data['x_end'][i]
                        route2['y_end']=data['y_end'][i]
                        route2['origin']=data['origin'][i]
                        route2['destination']=data['destination'][i]
                        route2['start_zone']=data['start_zone'][i]
                        route2['end_zone']=data['end_zone'][i]
                except:
                    pass         

        clear_button.click() # click to Reset button
        counter+=1
        print('counter:',counter)
        
    except:
        driver.quit() # close the webpage if the loop failed to scrape while works !
        
driver.quit()# close the webpage after finishing the main loop
# Out:
# counter: 1
# counter: 2
# counter: 3

# %%
cengiz
# Out:
# [{0: 'From 4110 Mystic Valley Pkwy, Medford, MA 02155, USA to 75 Quincy St, Medford, MA 02155, USA',
#   'direction': {0: 'From Mystic Valley Pkwy Westbound to Alewife Brook Pkwy Southbound',
#    1: 'Alewife Brook Pkwy Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.4051334,
#   'y_start': -71.0825552,
#   'x_end': 42.410869,
#   'y_end': -71.127038,
#   'origin': '42.4051334, -71.0825552',
#   'destination': '42.410869, -71.127038',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 10 min',
#   2: ' 3.7 miles'},
#  {0: 'From 4110 Mystic Valley Pkwy, Medford, MA 02155, USA to 75 Quincy St, Medford, MA 02155, USA',
#   'direction': {0: 'From Mystic Valley Pkwy Westbound to Harvard St Westbound',
#    1: 'From Harvard St Westbound to Warner St Westbound',
#    2: 'From Warner St Westbound to Powder House Sq Westbound',
#    3: 'From Powder House Sq Westbound to Powder House Blvd Westbound',
#    4: 'From Powder House Blvd Westbound to Alewife Brook Pkwy Northbound',
#    5: 'Alewife Brook Pkwy Northbound'},
#   'route': 'Route 2',
#   'x_start': 42.4051334,
#   'y_start': -71.0825552,
#   'x_end': 42.410869,
#   'y_end': -71.127038,
#   'origin': '42.4051334, -71.0825552',
#   'destination': '42.410869, -71.127038',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 8 min',
#   2: ' 2.9 miles'},
#  {0: 'From 21 Naomi St, Malden, MA 02148, USA to 616 Fellsway, Medford, MA 02155, USA',
#   'direction': {0: 'From Naomi St Westbound to Savin St Southbound',
#    1: 'From Savin St Southbound to Cushing Rd Southbound',
#    2: 'From Cushing Rd Southbound to Fellsmere Rd Southbound',
#    3: 'From Fellsmere Rd Southbound to Savin St Westbound',
#    4: 'From Savin St Westbound to Fellsmere Rd Eastbound',
#    5: 'From Fellsmere Rd Eastbound to W Border Rd Southbound',
#    6: 'From W Border Rd Southbound to Fellsway E Southbound',
#    7: 'From Fellsway E Southbound to Fellsway Southbound',
#    8: 'Fellsway Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.4333703,
#   'y_start': -71.08790450000001,
#   'x_end': 42.4057258,
#   'y_end': -71.08234470000001,
#   'origin': '42.4333703, -71.08790450000001',
#   'destination': '42.4057258, -71.08234470000001',
#   'start_zone': 1,
#   'end_zone': 2,
#   1: ' 5 min',
#   2: ' 2.1 miles'},
#  {},
#  {0: 'From 5 Revere Beach Pkwy, Medford, MA 02155, USA to Fairmount House, 21 Fairmount St, Medford, MA 02155, USA',
#   'direction': {0: 'From Revere Beach Pkwy Eastbound to Station Lndg Southbound',
#    1: 'From Station Lndg Southbound to Fellsway Northbound',
#    2: 'From Fellsway Northbound to Mystic Valley Pkwy Westbound',
#    3: 'From Mystic Valley Pkwy Westbound to Harvard St Westbound',
#    4: 'From Harvard St Westbound to Boston Ave Northbound',
#    5: 'From Boston Ave Northbound to Dearborn Rd Westbound',
#    6: 'From Dearborn Rd Westbound to College Ave Northbound',
#    7: 'From College Ave Northbound to Professors Row Westbound',
#    8: 'From Professors Row Westbound to Packard Ave Northbound',
#    9: 'From Packard Ave Northbound to Capen St E Westbound',
#    10: 'Capen St E Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.404602600000004,
#   'y_start': -71.0809975,
#   'x_end': 42.4098316,
#   'y_end': -71.1211007,
#   'origin': '42.404602600000004, -71.0809975',
#   'destination': '42.4098316, -71.1211007',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 12 min',
#   2: ' 2.8 miles'},
#  {0: 'From 5 Revere Beach Pkwy, Medford, MA 02155, USA to Fairmount House, 21 Fairmount St, Medford, MA 02155, USA',
#   'direction': {0: 'From Revere Beach Pkwy Eastbound to Station Lndg Southbound',
#    1: 'From Station Lndg Southbound to Earhart Lndg Westbound',
#    2: 'From Earhart Lndg Westbound to Fellsway Northbound',
#    3: 'From Fellsway Northbound to Mystic Valley Pkwy Westbound',
#    4: 'From Mystic Valley Pkwy Westbound to Harvard St Westbound',
#    5: 'From Harvard St Westbound to Warner St Westbound',
#    6: 'From Warner St Westbound to Powder House Sq Westbound',
#    7: 'From Powder House Sq Westbound to Powder House Blvd Westbound',
#    8: 'From Powder House Blvd Westbound to Packard Ave Northbound',
#    9: 'From Packard Ave Northbound to Capen St E Westbound',
#    10: 'Capen St E Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.404602600000004,
#   'y_start': -71.0809975,
#   'x_end': 42.4098316,
#   'y_end': -71.1211007,
#   'origin': '42.404602600000004, -71.0809975',
#   'destination': '42.4098316, -71.1211007',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 10 min',
#   2: ' 3.1 miles'},
#  {0: 'From 194 Fells Ave, Medford, MA 02155, USA to 69 Bradbury Ave, Medford, MA 02155, USA',
#   'direction': {0: 'From Fells Ave Eastbound to Murray Hill Rd Eastbound',
#    1: 'From Murray Hill Rd Eastbound to Fellsway E Southbound',
#    2: 'From Fellsway E Southbound to Pleasant St Eastbound',
#    3: 'From Pleasant St Eastbound to Fellsway E Southbound',
#    4: 'From Fellsway E Southbound to Fellsway Southbound',
#    5: 'From Fellsway Southbound to Riverside Ave Eastbound',
#    6: 'From Riverside Ave Eastbound to Bradbury Ave Northbound',
#    7: 'From Bradbury Ave Northbound to 3Rd St Eastbound',
#    8: '3Rd St Eastbound'},
#   'route': 'Route 1',
#   'x_start': 42.4278883,
#   'y_start': -71.09503240000001,
#   'x_end': 42.4107101,
#   'y_end': -71.0816604,
#   'origin': '42.4278883, -71.09503240000001',
#   'destination': '42.4107101, -71.0816604',
#   'start_zone': 1,
#   'end_zone': 2,
#   1: ' 5 min',
#   2: ' 2.0 miles'},
#  {},
#  {0: 'From 606 Fulton St, Medford, MA 02155, USA to 80 Station Landing, Medford, MA 02155, USA',
#   'direction': {0: 'From Fulton St Northbound to Gaston St Westbound',
#    1: 'From Gaston St Westbound to Haines St Westbound',
#    2: 'From Haines St Westbound to Elm St Westbound',
#    3: 'From Elm St Westbound to Fellsway W Southbound',
#    4: 'From Fellsway W Southbound to Roosevelt Cir Westbound',
#    5: 'From Roosevelt Cir Westbound to Fellsway W Southbound',
#    6: 'From Fellsway W Southbound to I-93 Southbound',
#    7: 'From I-93 Southbound to Mystic Valley Pkwy Eastbound',
#    8: 'From Mystic Valley Pkwy Eastbound to Revere Beach Pkwy Eastbound',
#    9: 'From Revere Beach Pkwy Eastbound to Constitution Way Southbound',
#    10: 'Constitution Way Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.4381877,
#   'y_start': -71.0935869,
#   'x_end': 42.40176029999999,
#   'y_end': -71.0802975,
#   'origin': '42.4381877, -71.0935869',
#   'destination': '42.40176029999999, -71.0802975',
#   'start_zone': 1,
#   'end_zone': 2,
#   1: ' 8 min',
#   2: ' 4.0 miles'},
#  {0: 'From 606 Fulton St, Medford, MA 02155, USA to 80 Station Landing, Medford, MA 02155, USA',
#   'direction': {0: 'From Fulton St Southbound to Park Ave Eastbound',
#    1: 'From Park Ave Eastbound to Highland Ter Eastbound',
#    2: 'From Highland Ter Eastbound to Highland Ave Eastbound',
#    3: 'From Highland Ave Eastbound to Fellsway E Southbound',
#    4: 'From Fellsway E Southbound to Fellsway Southbound',
#    5: 'From Fellsway Southbound to Mystic Valley Pkwy Eastbound',
#    6: 'From Mystic Valley Pkwy Eastbound to Revere Beach Pkwy Eastbound',
#    7: 'From Revere Beach Pkwy Eastbound to Constitution Way Southbound',
#    8: 'Constitution Way Southbound'},
#   'route': 'Route 2',
#   'x_start': 42.4381877,
#   'y_start': -71.0935869,
#   'x_end': 42.40176029999999,
#   'y_end': -71.0802975,
#   'origin': '42.4381877, -71.0935869',
#   'destination': '42.40176029999999, -71.0802975',
#   'start_zone': 1,
#   'end_zone': 2,
#   1: ' 8 min',
#   2: ' 3.2 miles'},
#  {0: 'From 1 Wilson St, Medford, MA 02155, USA to 76 Hillsdale Rd, Medford, MA 02155, USA',
#   'direction': {0: 'From Wilson St Northbound to Mangles St Westbound',
#    1: 'From Mangles St Westbound to Harrison St Southbound',
#    2: 'From Harrison St Southbound to Winslow Ave Westbound',
#    3: 'From Winslow Ave Westbound to Mccormack Ave Southbound',
#    4: 'From Mccormack Ave Southbound to Lila Ave Westbound',
#    5: 'From Lila Ave Westbound to Fulton St Southbound',
#    6: 'From Fulton St Southbound to Newport Ave Westbound',
#    7: 'From Newport Ave Westbound to Fountain St Southbound',
#    8: 'From Fountain St Southbound to Webster St Westbound',
#    9: 'From Webster St Westbound to Brookside Pkwy Southbound',
#    10: 'From Brookside Pkwy Southbound to Salem St Westbound',
#    11: 'From Salem St Westbound to Rt-60 Westbound',
#    12: 'From Rt-60 Westbound to Main St Westbound',
#    13: 'From Main St Westbound to Summer St Westbound',
#    14: 'From Summer St Westbound to Winthrop St Southbound',
#    15: 'From Winthrop St Southbound to Tesla Ave Westbound',
#    16: 'Tesla Ave Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.4334053,
#   'y_start': -71.090581,
#   'x_end': 42.410281700000006,
#   'y_end': -71.125489,
#   'origin': '42.4334053, -71.090581',
#   'destination': '42.410281700000006, -71.125489',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 12 min',
#   2: ' 3.3 miles'},
#  {0: 'From 1 Wilson St, Medford, MA 02155, USA to 76 Hillsdale Rd, Medford, MA 02155, USA',
#   'direction': {0: 'From Wilson St Northbound to Mangles St Westbound',
#    1: 'From Mangles St Westbound to Harrison St Southbound',
#    2: 'From Harrison St Southbound to Winslow Ave Westbound',
#    3: 'From Winslow Ave Westbound to Mccormack Ave Southbound',
#    4: 'From Mccormack Ave Southbound to Lila Ave Westbound',
#    5: 'From Lila Ave Westbound to Fulton St Southbound',
#    6: 'From Fulton St Southbound to Foss St Westbound',
#    7: 'From Foss St Westbound to Fellsway W Northbound',
#    8: 'From Fellsway W Northbound to Elm St Westbound',
#    9: 'From Elm St Westbound to Fellsway W Southbound',
#    10: 'From Fellsway W Southbound to Roosevelt Cir Westbound',
#    11: 'From Roosevelt Cir Westbound to Fellsway W Southbound',
#    12: 'From Fellsway W Southbound to I-93 Southbound',
#    13: 'From I-93 Southbound to Salem St Westbound',
#    14: 'From Salem St Westbound to Rt-60 Westbound',
#    15: 'From Rt-60 Westbound to High St Westbound',
#    16: 'From High St Westbound to Winthrop St Southbound',
#    17: 'From Winthrop St Southbound to Rt-38 Southbound',
#    18: 'From Rt-38 Southbound to Winthrop St Southbound',
#    19: 'From Winthrop St Southbound to Tesla Ave Westbound',
#    20: 'Tesla Ave Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.4334053,
#   'y_start': -71.090581,
#   'x_end': 42.410281700000006,
#   'y_end': -71.125489,
#   'origin': '42.4334053, -71.090581',
#   'destination': '42.410281700000006, -71.125489',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 10 min',
#   2: ' 3.9 miles'},
#  {0: 'From 63 Charnwood Rd, Medford, MA 02155, USA to Middlesex Ave @ Third St, Medford, MA 02155, USA',
#   'direction': {0: 'From Charnwood Rd Eastbound to Benham St Northbound',
#    1: 'From Benham St Northbound to Chester Ave Eastbound',
#    2: 'From Chester Ave Eastbound to Brookings St Northbound',
#    3: 'From Brookings St Northbound to George St Eastbound',
#    4: 'From George St Eastbound to College Ave Southbound',
#    5: 'From College Ave Southbound to Pearl St Eastbound',
#    6: 'From Pearl St Eastbound to Main St Southbound',
#    7: 'From Main St Southbound to Hancock St Eastbound',
#    8: 'From Hancock St Eastbound to Mystic Ave Southbound',
#    9: 'From Mystic Ave Southbound to Mystic Valley Pkwy Eastbound',
#    10: 'From Mystic Valley Pkwy Eastbound to Middlesex Ave Northbound',
#    11: 'Middlesex Ave Northbound'},
#   'route': 'Route 1',
#   'x_start': 42.411164,
#   'y_start': -71.119392,
#   'x_end': 42.410299,
#   'y_end': -71.07961800000001,
#   'origin': '42.411164, -71.119392',
#   'destination': '42.410299, -71.07961800000001',
#   'start_zone': 0,
#   'end_zone': 2,
#   1: ' 9 min',
#   2: ' 2.9 miles'},
#  {0: 'From 63 Charnwood Rd, Medford, MA 02155, USA to Middlesex Ave @ Third St, Medford, MA 02155, USA',
#   'direction': {0: 'From Charnwood Rd Westbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to I-93 Southbound',
#    4: 'From I-93 Southbound to Mystic Valley Pkwy Eastbound',
#    5: 'From Mystic Valley Pkwy Eastbound to Middlesex Ave Northbound',
#    6: 'Middlesex Ave Northbound'},
#   'route': 'Route 2',
#   'x_start': 42.411164,
#   'y_start': -71.119392,
#   'x_end': 42.410299,
#   'y_end': -71.07961800000001,
#   'origin': '42.411164, -71.119392',
#   'destination': '42.410299, -71.07961800000001',
#   'start_zone': 0,
#   'end_zone': 2,
#   1: ' 8 min',
#   2: ' 3.4 miles'},
#  {0: 'From 1956 Rivers Edge Dr, Medford, MA 02155, USA to 63 Charnwood Rd, Medford, MA 02155, USA',
#   'direction': {0: 'From Revere Beach Pkwy Westbound to Mystic Valley Pkwy Westbound',
#    1: 'From Mystic Valley Pkwy Westbound to Mystic Ave Northbound',
#    2: 'From Mystic Ave Northbound to Hancock St Westbound',
#    3: 'From Hancock St Westbound to Main St Northbound',
#    4: 'From Main St Northbound to Stearns Ave Westbound',
#    5: 'From Stearns Ave Westbound to College Ave Northbound',
#    6: 'From College Ave Northbound to George St Westbound',
#    7: 'From George St Westbound to Burget Ave Southbound',
#    8: 'From Burget Ave Southbound to Chester Ave Westbound',
#    9: 'From Chester Ave Westbound to Brookings St Southbound',
#    10: 'From Brookings St Southbound to Greenleaf Ave Westbound',
#    11: 'From Greenleaf Ave Westbound to Benham St Southbound',
#    12: 'From Benham St Southbound to Charnwood Rd Westbound',
#    13: 'Charnwood Rd Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.4041002,
#   'y_start': -71.07673929999999,
#   'x_end': 42.411164,
#   'y_end': -71.119392,
#   'origin': '42.4041002, -71.07673929999999',
#   'destination': '42.411164, -71.119392',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 7 min',
#   2: ' 2.8 miles'},
#  {0: 'From 1956 Rivers Edge Dr, Medford, MA 02155, USA to 63 Charnwood Rd, Medford, MA 02155, USA',
#   'direction': {0: 'From Revere Beach Pkwy Westbound to Mystic Valley Pkwy Westbound',
#    1: 'From Mystic Valley Pkwy Westbound to Mystic Ave Northbound',
#    2: 'From Mystic Ave Northbound to Hancock St Westbound',
#    3: 'From Hancock St Westbound to Main St Northbound',
#    4: 'From Main St Northbound to George St Westbound',
#    5: 'From George St Westbound to Burget Ave Southbound',
#    6: 'From Burget Ave Southbound to Chester Ave Westbound',
#    7: 'From Chester Ave Westbound to Brookings St Southbound',
#    8: 'From Brookings St Southbound to Greenleaf Ave Westbound',
#    9: 'From Greenleaf Ave Westbound to Benham St Southbound',
#    10: 'From Benham St Southbound to Charnwood Rd Westbound',
#    11: 'Charnwood Rd Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.4041002,
#   'y_start': -71.07673929999999,
#   'x_end': 42.411164,
#   'y_end': -71.119392,
#   'origin': '42.4041002, -71.07673929999999',
#   'destination': '42.411164, -71.119392',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 7 min',
#   2: ' 2.8 miles'},
#  {0: 'From 10 Winthrop St, Medford, MA 02155, USA to 2 Sawyer St, Medford, MA 02155, USA',
#   'direction': {0: 'From Tesla Ave Eastbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to I-93 Northbound',
#    4: 'From I-93 Northbound to Fellsway W Northbound',
#    5: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    6: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    7: 'From Fellsway W Northbound to Foss St Eastbound',
#    8: 'From Foss St Eastbound to Fulton St Northbound',
#    9: 'From Fulton St Northbound to Lila Ave Eastbound',
#    10: 'From Lila Ave Eastbound to Mccormack Ave Northbound',
#    11: 'From Mccormack Ave Northbound to Winslow Ave Eastbound',
#    12: 'From Winslow Ave Eastbound to Harrison St Northbound',
#    13: 'From Harrison St Northbound to Mangles St Eastbound',
#    14: 'From Mangles St Eastbound to Morrison St Northbound',
#    15: 'From Morrison St Northbound to Clematis Rd Eastbound',
#    16: 'From Clematis Rd Eastbound to Doonan St Southbound',
#    17: 'From Doonan St Southbound to Bowen St Westbound',
#    18: 'From Bowen St Westbound to Sawyer St Northbound',
#    19: 'Sawyer St Northbound'},
#   'route': 'Route 1',
#   'x_start': 42.409608,
#   'y_start': -71.123088,
#   'x_end': 42.432587,
#   'y_end': -71.0905484,
#   'origin': '42.409608, -71.123088',
#   'destination': '42.432587, -71.0905484',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 10 min',
#   2: ' 4.5 miles'},
#  {0: 'From 10 Winthrop St, Medford, MA 02155, USA to 2 Sawyer St, Medford, MA 02155, USA',
#   'direction': {0: 'From Tesla Ave Eastbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to South St Eastbound',
#    4: 'From South St Eastbound to Main St Northbound',
#    5: 'From Main St Northbound to Riverside Ave Eastbound',
#    6: 'From Riverside Ave Eastbound to City Hall Mall Northbound',
#    7: 'From City Hall Mall Northbound to Salem St Eastbound',
#    8: 'From Salem St Eastbound to Rt-60 Eastbound',
#    9: 'From Rt-60 Eastbound to I-93 Northbound',
#    10: 'From I-93 Northbound to Fellsway W Northbound',
#    11: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    12: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    13: 'From Fellsway W Northbound to Foss St Eastbound',
#    14: 'From Foss St Eastbound to Fulton St Northbound',
#    15: 'From Fulton St Northbound to Lila Ave Eastbound',
#    16: 'From Lila Ave Eastbound to Mccormack Ave Northbound',
#    17: 'From Mccormack Ave Northbound to Winslow Ave Eastbound',
#    18: 'From Winslow Ave Eastbound to Harrison St Northbound',
#    19: 'From Harrison St Northbound to Mangles St Eastbound',
#    20: 'From Mangles St Eastbound to Morrison St Northbound',
#    21: 'From Morrison St Northbound to Clematis Rd Eastbound',
#    22: 'From Clematis Rd Eastbound to Doonan St Southbound',
#    23: 'From Doonan St Southbound to Bowen St Westbound',
#    24: 'From Bowen St Westbound to Sawyer St Northbound',
#    25: 'Sawyer St Northbound'},
#   'route': 'Route 2',
#   'x_start': 42.409608,
#   'y_start': -71.123088,
#   'x_end': 42.432587,
#   'y_end': -71.0905484,
#   'origin': '42.409608, -71.123088',
#   'destination': '42.432587, -71.0905484',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 11 min',
#   2: ' 3.9 miles'},
#  {0: 'From Stop & Shop - New England, 760 Fellsway, Medford, MA 02155, United States to 40 Tesla Ave, Medford, MA 02155, USA',
#   'direction': {0: 'From Fellsway Southbound to Mystic Valley Pkwy Westbound',
#    1: 'From Mystic Valley Pkwy Westbound to Harvard St Westbound',
#    2: 'From Harvard St Westbound to Warner St Westbound',
#    3: 'From Warner St Westbound to Powder House Sq Westbound',
#    4: 'From Powder House Sq Westbound to Powder House Blvd Westbound',
#    5: 'From Powder House Blvd Westbound to Curtis St Northbound',
#    6: 'From Curtis St Northbound to Winthrop St Northbound',
#    7: 'From Winthrop St Northbound to Tesla Ave Westbound',
#    8: 'Tesla Ave Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.4101073,
#   'y_start': -71.084727,
#   'x_end': 42.410028999999994,
#   'y_end': -71.124367,
#   'origin': '42.4101073, -71.084727',
#   'destination': '42.410028999999994, -71.124367',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 9 min',
#   2: ' 3.3 miles'},
#  {0: 'From Stop & Shop - New England, 760 Fellsway, Medford, MA 02155, United States to 40 Tesla Ave, Medford, MA 02155, USA',
#   'direction': {0: 'From Fellsway Southbound to Riverside Ave Westbound',
#    1: 'From Riverside Ave Westbound to Locust St Southbound',
#    2: 'From Locust St Southbound to Mystic Valley Pkwy Westbound',
#    3: 'From Mystic Valley Pkwy Westbound to Harvard St Westbound',
#    4: 'From Harvard St Westbound to Boston Ave Northbound',
#    5: 'From Boston Ave Northbound to College Ave Northbound',
#    6: 'From College Ave Northbound to Boston Ave Northbound',
#    7: 'From Boston Ave Northbound to Winthrop St Southbound',
#    8: 'From Winthrop St Southbound to Tesla Ave Westbound',
#    9: 'Tesla Ave Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.4101073,
#   'y_start': -71.084727,
#   'x_end': 42.410028999999994,
#   'y_end': -71.124367,
#   'origin': '42.4101073, -71.084727',
#   'destination': '42.410028999999994, -71.124367',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 10 min',
#   2: ' 2.9 miles'},
#  {0: 'From 676 Fulton St, Medford, MA 02155, USA to 138 Brookings St, Medford, MA 02155, USA',
#   'direction': {0: 'From Wason St Westbound to Sturges St Westbound',
#    1: 'From Sturges St Westbound to Elm St Southbound',
#    2: 'From Elm St Southbound to Fellsway W Southbound',
#    3: 'From Fellsway W Southbound to Roosevelt Cir Westbound',
#    4: 'From Roosevelt Cir Westbound to Fellsway W Southbound',
#    5: 'From Fellsway W Southbound to I-93 Southbound',
#    6: 'From I-93 Southbound to Salem St Westbound',
#    7: 'From Salem St Westbound to Rt-60 Westbound',
#    8: 'From Rt-60 Westbound to Main St Westbound',
#    9: 'From Main St Westbound to Summer St Westbound',
#    10: 'From Summer St Westbound to Brookings St Southbound',
#    11: 'Brookings St Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.439910999999995,
#   'y_start': -71.094349,
#   'x_end': 42.410403,
#   'y_end': -71.11893,
#   'origin': '42.439910999999995, -71.094349',
#   'destination': '42.410403, -71.11893',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 8 min',
#   2: ' 3.0 miles'},
#  {0: 'From 676 Fulton St, Medford, MA 02155, USA to 138 Brookings St, Medford, MA 02155, USA',
#   'direction': {0: 'From Wason St Westbound to Sturges St Westbound',
#    1: 'From Sturges St Westbound to Elm St Southbound',
#    2: 'From Elm St Southbound to Fellsway W Southbound',
#    3: 'From Fellsway W Southbound to Roosevelt Cir Westbound',
#    4: 'From Roosevelt Cir Westbound to Fellsway W Southbound',
#    5: 'From Fellsway W Southbound to I-93 Southbound',
#    6: 'From I-93 Southbound to Salem St Westbound',
#    7: 'From Salem St Westbound to Rt-60 Westbound',
#    8: 'From Rt-60 Westbound to Main St Westbound',
#    9: 'From Main St Westbound to George St Westbound',
#    10: 'From George St Westbound to Burget Ave Southbound',
#    11: 'From Burget Ave Southbound to Chester Ave Westbound',
#    12: 'From Chester Ave Westbound to Brookings St Southbound',
#    13: 'Brookings St Southbound'},
#   'route': 'Route 2',
#   'x_start': 42.439910999999995,
#   'y_start': -71.094349,
#   'x_end': 42.410403,
#   'y_end': -71.11893,
#   'origin': '42.439910999999995, -71.094349',
#   'destination': '42.410403, -71.11893',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 8 min',
#   2: ' 3.0 miles'},
#  {0: 'From 10 Winthrop St, Medford, MA 02155, USA to 31 Mccall St, Medford, MA 02155, USA',
#   'direction': {0: 'From Tesla Ave Eastbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to I-93 Northbound',
#    4: 'From I-93 Northbound to Fellsway W Northbound',
#    5: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    6: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    7: 'From Fellsway W Northbound to Elm St Eastbound',
#    8: 'From Elm St Eastbound to Fulton St Southbound',
#    9: 'From Fulton St Southbound to Mccall St Eastbound',
#    10: 'Mccall St Eastbound'},
#   'route': 'Route 1',
#   'x_start': 42.409608,
#   'y_start': -71.123088,
#   'x_end': 42.4407625,
#   'y_end': -71.0930686,
#   'origin': '42.409608, -71.123088',
#   'destination': '42.4407625, -71.0930686',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 9 min',
#   2: ' 4.3 miles'},
#  {0: 'From 10 Winthrop St, Medford, MA 02155, USA to 31 Mccall St, Medford, MA 02155, USA',
#   'direction': {0: 'From Tesla Ave Eastbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to South St Eastbound',
#    4: 'From South St Eastbound to Main St Northbound',
#    5: 'From Main St Northbound to Riverside Ave Eastbound',
#    6: 'From Riverside Ave Eastbound to City Hall Mall Northbound',
#    7: 'From City Hall Mall Northbound to Salem St Eastbound',
#    8: 'From Salem St Eastbound to Rt-60 Eastbound',
#    9: 'From Rt-60 Eastbound to I-93 Northbound',
#    10: 'From I-93 Northbound to Fellsway W Northbound',
#    11: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    12: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    13: 'From Fellsway W Northbound to Elm St Eastbound',
#    14: 'From Elm St Eastbound to Sturges St Eastbound',
#    15: 'From Sturges St Eastbound to Wason St Eastbound',
#    16: 'From Wason St Eastbound to Mccall St Westbound',
#    17: 'Mccall St Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.409608,
#   'y_start': -71.123088,
#   'x_end': 42.4407625,
#   'y_end': -71.0930686,
#   'origin': '42.409608, -71.123088',
#   'destination': '42.4407625, -71.0930686',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 10 min',
#   2: ' 3.7 miles'},
#  {0: 'From 592 Fulton St, Medford, MA 02155, USA to 4000 Mystic Valley Pkwy, Medford, MA 02155, USA',
#   'direction': {0: 'From Fulton St Westbound to Walsh St Westbound',
#    1: 'From Walsh St Westbound to Brackett St Westbound',
#    2: 'From Brackett St Westbound to Elm St Westbound',
#    3: 'From Elm St Westbound to Fellsway W Southbound',
#    4: 'From Fellsway W Southbound to Roosevelt Cir Westbound',
#    5: 'From Roosevelt Cir Westbound to Fellsway W Southbound',
#    6: 'From Fellsway W Southbound to I-93 Southbound',
#    7: 'From I-93 Southbound to Mystic Valley Pkwy Eastbound',
#    8: 'From Mystic Valley Pkwy Eastbound to Commercial St Northbound',
#    9: 'Commercial St Northbound'},
#   'route': 'Route 1',
#   'x_start': 42.4378185,
#   'y_start': -71.0938114,
#   'x_end': 42.4039865,
#   'y_end': -71.0889423,
#   'origin': '42.4378185, -71.0938114',
#   'destination': '42.4039865, -71.0889423',
#   'start_zone': 1,
#   'end_zone': 2,
#   1: ' 7 min',
#   2: ' 3.6 miles'},
#  {0: 'From 592 Fulton St, Medford, MA 02155, USA to 4000 Mystic Valley Pkwy, Medford, MA 02155, USA',
#   'direction': {0: 'From Fulton St Westbound to Newport Ave Westbound',
#    1: 'From Newport Ave Westbound to Fountain St Southbound',
#    2: 'From Fountain St Southbound to Webster St Westbound',
#    3: 'From Webster St Westbound to Brookside Pkwy Southbound',
#    4: 'From Brookside Pkwy Southbound to I-93 Southbound',
#    5: 'From I-93 Southbound to Mystic Valley Pkwy Eastbound',
#    6: 'From Mystic Valley Pkwy Eastbound to Commercial St Northbound',
#    7: 'Commercial St Northbound'},
#   'route': 'Route 2',
#   'x_start': 42.4378185,
#   'y_start': -71.0938114,
#   'x_end': 42.4039865,
#   'y_end': -71.0889423,
#   'origin': '42.4378185, -71.0938114',
#   'destination': '42.4039865, -71.0889423',
#   'start_zone': 1,
#   'end_zone': 2,
#   1: ' 8 min',
#   2: ' 3.4 miles'},
#  {0: 'From 33 Doonan St, Medford, MA 02155, USA to 699 Fellsway, Medford, MA 02155, USA',
#   'direction': {0: 'From Doonan St Southbound to Short St Eastbound',
#    1: 'From Short St Eastbound to Richard St Northbound',
#    2: 'From Richard St Northbound to Rita Dr Eastbound',
#    3: 'From Rita Dr Eastbound to Highland Ave Eastbound',
#    4: 'From Highland Ave Eastbound to Fellsway E Southbound',
#    5: 'From Fellsway E Southbound to Fellsway Southbound',
#    6: 'From Fellsway Southbound to Riverside Ave Eastbound',
#    7: 'From Riverside Ave Eastbound to Mcdonald Rd Southbound',
#    8: 'Mcdonald Rd Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.434034999999994,
#   'y_start': -71.08961500000001,
#   'x_end': 42.408258200000006,
#   'y_end': -71.0833609,
#   'origin': '42.434034999999994, -71.08961500000001',
#   'destination': '42.408258200000006, -71.0833609',
#   'start_zone': 1,
#   'end_zone': 2,
#   1: ' 7 min',
#   2: ' 2.6 miles'},
#  {},
#  {0: 'From 75 Quincy St, Medford, MA 02155, USA to 101 Locust St, Medford, MA 02155, USA',
#   'direction': {0: 'From Osgood St Westbound to North St Northbound',
#    1: 'From North St Northbound to Woods Ave Westbound',
#    2: 'From Woods Ave Westbound to Alewife Brook Pkwy Northbound',
#    3: 'From Alewife Brook Pkwy Northbound to Mystic Valley Pkwy Northbound',
#    4: 'From Mystic Valley Pkwy Northbound to I-93 Southbound',
#    5: 'From I-93 Southbound to Mystic Valley Pkwy Eastbound',
#    6: 'Mystic Valley Pkwy Eastbound'},
#   'route': 'Route 1',
#   'x_start': 42.410869,
#   'y_start': -71.127038,
#   'x_end': 42.4059703,
#   'y_end': -71.0949567,
#   'origin': '42.410869, -71.127038',
#   'destination': '42.4059703, -71.0949567',
#   'start_zone': 0,
#   'end_zone': 2,
#   1: ' 12 min',
#   2: ' 2.8 miles'},
#  {0: 'From 75 Quincy St, Medford, MA 02155, USA to 101 Locust St, Medford, MA 02155, USA',
#   'direction': {0: 'From Osgood St Eastbound to Hillsdale Rd Northbound',
#    1: 'From Hillsdale Rd Northbound to Tesla Ave Eastbound',
#    2: 'From Tesla Ave Eastbound to Winthrop St Northbound',
#    3: 'From Winthrop St Northbound to Rt-38 Northbound',
#    4: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    5: 'From Mystic Valley Pkwy Eastbound to I-93 Southbound',
#    6: 'From I-93 Southbound to Mystic Valley Pkwy Eastbound',
#    7: 'Mystic Valley Pkwy Eastbound'},
#   'route': 'Route 2',
#   'x_start': 42.410869,
#   'y_start': -71.127038,
#   'x_end': 42.4059703,
#   'y_end': -71.0949567,
#   'origin': '42.410869, -71.127038',
#   'destination': '42.4059703, -71.0949567',
#   'start_zone': 0,
#   'end_zone': 2,
#   1: ' 6 min',
#   2: ' 2.6 miles'},
#  {0: 'From 807-817 MA-28, Medford, MA 02155, USA to 43 Winthrop St, Medford, MA 02155, USA',
#   'direction': {0: 'From 4Th St Westbound to Fellsway Northbound',
#    1: 'From Fellsway Northbound to 3Rd St Eastbound',
#    2: 'From 3Rd St Eastbound to Bradbury Ave Southbound',
#    3: 'From Bradbury Ave Southbound to Riverside Ave Westbound',
#    4: 'From Riverside Ave Westbound to Fellsway Southbound',
#    5: 'From Fellsway Southbound to Mystic Valley Pkwy Westbound',
#    6: 'From Mystic Valley Pkwy Westbound to Mystic Ave Northbound',
#    7: 'From Mystic Ave Northbound to Hancock St Westbound',
#    8: 'From Hancock St Westbound to Main St Northbound',
#    9: 'From Main St Northbound to Stearns Ave Westbound',
#    10: 'From Stearns Ave Westbound to College Ave Northbound',
#    11: 'From College Ave Northbound to George St Westbound',
#    12: 'From George St Westbound to Burget Ave Southbound',
#    13: 'From Burget Ave Southbound to Chester Ave Westbound',
#    14: 'From Chester Ave Westbound to Winthrop St Southbound',
#    15: 'Winthrop St Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.411069,
#   'y_start': -71.084974,
#   'x_end': 42.410717,
#   'y_end': -71.122337,
#   'origin': '42.411069, -71.084974',
#   'destination': '42.410717, -71.122337',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 9 min',
#   2: ' 3.5 miles'},
#  {0: 'From 807-817 MA-28, Medford, MA 02155, USA to 43 Winthrop St, Medford, MA 02155, USA',
#   'direction': {0: 'From 4Th St Westbound to Fellsway Northbound',
#    1: 'From Fellsway Northbound to Central Ave Westbound',
#    2: 'From Central Ave Westbound to Park St Southbound',
#    3: 'From Park St Southbound to Franklin St Westbound',
#    4: 'From Franklin St Westbound to Hadley Pl Northbound',
#    5: 'From Hadley Pl Northbound to Salem St Westbound',
#    6: 'From Salem St Westbound to Rt-60 Westbound',
#    7: 'From Rt-60 Westbound to Main St Westbound',
#    8: 'From Main St Westbound to Summer St Westbound',
#    9: 'From Summer St Westbound to Winthrop St Southbound',
#    10: 'Winthrop St Southbound'},
#   'route': 'Route 2',
#   'x_start': 42.411069,
#   'y_start': -71.084974,
#   'x_end': 42.410717,
#   'y_end': -71.122337,
#   'origin': '42.411069, -71.084974',
#   'destination': '42.410717, -71.122337',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 12 min',
#   2: ' 3.4 miles'},
#  {0: 'From 25 Capen St E, Medford, MA 02155, USA to 250 E Border Rd, Medford, MA 02155, USA',
#   'direction': {0: 'From Capen St Eastbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to I-93 Northbound',
#    4: 'From I-93 Northbound to Fellsway W Northbound',
#    5: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    6: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    7: 'From Fellsway W Northbound to Elm St Eastbound',
#    8: 'From Elm St Eastbound to Highland Ave Eastbound',
#    9: 'From Highland Ave Eastbound to E Border Rd Eastbound',
#    10: 'From E Border Rd Eastbound to Maurice St Westbound',
#    11: 'Maurice St Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.411082,
#   'y_start': -71.123696,
#   'x_end': 42.4407002,
#   'y_end': -71.087127,
#   'origin': '42.411082, -71.123696',
#   'destination': '42.4407002, -71.087127',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 9 min',
#   2: ' 4.6 miles'},
#  {0: 'From 25 Capen St E, Medford, MA 02155, USA to 250 E Border Rd, Medford, MA 02155, USA',
#   'direction': {0: 'From Capen St Eastbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to South St Eastbound',
#    4: 'From South St Eastbound to Main St Northbound',
#    5: 'From Main St Northbound to Riverside Ave Eastbound',
#    6: 'From Riverside Ave Eastbound to City Hall Mall Northbound',
#    7: 'From City Hall Mall Northbound to Salem St Eastbound',
#    8: 'From Salem St Eastbound to Rt-60 Eastbound',
#    9: 'From Rt-60 Eastbound to I-93 Northbound',
#    10: 'From I-93 Northbound to Fellsway W Northbound',
#    11: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    12: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    13: 'From Fellsway W Northbound to Elm St Eastbound',
#    14: 'From Elm St Eastbound to Sturges St Eastbound',
#    15: 'From Sturges St Eastbound to Wason St Eastbound',
#    16: 'From Wason St Eastbound to Highland Ave Eastbound',
#    17: 'From Highland Ave Eastbound to E Border Rd Eastbound',
#    18: 'From E Border Rd Eastbound to Maurice St Westbound',
#    19: 'Maurice St Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.411082,
#   'y_start': -71.123696,
#   'x_end': 42.4407002,
#   'y_end': -71.087127,
#   'origin': '42.411082, -71.123696',
#   'destination': '42.4407002, -71.087127',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 10 min',
#   2: ' 4.0 miles'},
#  {0: 'From 3780 Mystic Valley Pkwy, Medford, MA 02155, USA to 4 Rita Dr, Medford, MA 02155, USA',
#   'direction': {0: 'From Mystic Valley Pkwy Eastbound to Locust St Southbound',
#    1: 'From Locust St Southbound to Mystic Valley Pkwy Westbound',
#    2: 'From Mystic Valley Pkwy Westbound to Mystic Ave Eastbound',
#    3: 'From Mystic Ave Eastbound to I-93 Northbound',
#    4: 'From I-93 Northbound to Fellsway W Northbound',
#    5: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    6: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    7: 'From Fellsway W Northbound to Elm St Eastbound',
#    8: 'From Elm St Eastbound to Highland Ave Eastbound',
#    9: 'From Highland Ave Eastbound to Rita Dr Westbound',
#    10: 'Rita Dr Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.4062507,
#   'y_start': -71.09456479999999,
#   'x_end': 42.436313,
#   'y_end': -71.0873683,
#   'origin': '42.4062507, -71.09456479999999',
#   'destination': '42.436313, -71.0873683',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 9 min',
#   2: ' 4.9 miles'},
#  {0: 'From 3780 Mystic Valley Pkwy, Medford, MA 02155, USA to 4 Rita Dr, Medford, MA 02155, USA',
#   'direction': {0: 'From Mystic Valley Pkwy Eastbound to Locust St Northbound',
#    1: 'From Locust St Northbound to Riverside Ave Westbound',
#    2: 'From Riverside Ave Westbound to Spring St Northbound',
#    3: 'From Spring St Northbound to Salem St Eastbound',
#    4: 'From Salem St Eastbound to Rt-60 Eastbound',
#    5: 'From Rt-60 Eastbound to Salem St Eastbound',
#    6: 'From Salem St Eastbound to Pleasant St Eastbound',
#    7: 'From Pleasant St Eastbound to Fellsway E Northbound',
#    8: 'From Fellsway E Northbound to Highland Ave Westbound',
#    9: 'From Highland Ave Westbound to Rita Dr Westbound',
#    10: 'Rita Dr Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.4062507,
#   'y_start': -71.09456479999999,
#   'x_end': 42.436313,
#   'y_end': -71.0873683,
#   'origin': '42.4062507, -71.09456479999999',
#   'destination': '42.436313, -71.0873683',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 9 min',
#   2: ' 2.7 miles'},
#  {0: 'From 194 Fells Ave, Medford, MA 02155, USA to 71 Hillsdale Rd, Medford, MA 02155, USA',
#   'direction': {0: 'From Fells Ave Westbound to Vista Ave Westbound',
#    1: 'From Vista Ave Westbound to Fulton Spring Rd Westbound',
#    2: 'From Fulton Spring Rd Westbound to Fulton St Southbound',
#    3: 'From Fulton St Southbound to Newport Ave Westbound',
#    4: 'From Newport Ave Westbound to Fountain St Southbound',
#    5: 'From Fountain St Southbound to Webster St Westbound',
#    6: 'From Webster St Westbound to Brookside Pkwy Southbound',
#    7: 'From Brookside Pkwy Southbound to Salem St Westbound',
#    8: 'From Salem St Westbound to Rt-60 Westbound',
#    9: 'From Rt-60 Westbound to Main St Westbound',
#    10: 'From Main St Westbound to Mystic Valley Pkwy Westbound',
#    11: 'From Mystic Valley Pkwy Westbound to Boston Ave Eastbound',
#    12: 'From Boston Ave Eastbound to Adams St Southbound',
#    13: 'From Adams St Southbound to Osgood St Eastbound',
#    14: 'From Osgood St Eastbound to Hillsdale Rd Northbound',
#    15: 'Hillsdale Rd Northbound'},
#   'route': 'Route 1',
#   'x_start': 42.4278883,
#   'y_start': -71.09503240000001,
#   'x_end': 42.410395,
#   'y_end': -71.125404,
#   'origin': '42.4278883, -71.09503240000001',
#   'destination': '42.410395, -71.125404',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 12 min',
#   2: ' 3.2 miles'},
#  {0: 'From 194 Fells Ave, Medford, MA 02155, USA to 71 Hillsdale Rd, Medford, MA 02155, USA',
#   'direction': {0: 'From Fells Ave Westbound to Vista Ave Westbound',
#    1: 'From Vista Ave Westbound to Fulton Spring Rd Westbound',
#    2: 'From Fulton Spring Rd Westbound to Rosina St Westbound',
#    3: 'From Rosina St Westbound to Mammola Way Westbound',
#    4: 'From Mammola Way Westbound to Earl Ave Westbound',
#    5: 'From Earl Ave Westbound to Fulton St Eastbound',
#    6: 'From Fulton St Eastbound to Ridgeway Rd Westbound',
#    7: 'From Ridgeway Rd Westbound to Fellsway W Northbound',
#    8: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    9: 'From Roosevelt Cir Northbound to Fellsway W Southbound',
#    10: 'From Fellsway W Southbound to I-93 Southbound',
#    11: 'From I-93 Southbound to Salem St Westbound',
#    12: 'From Salem St Westbound to Rt-60 Westbound',
#    13: 'From Rt-60 Westbound to High St Westbound',
#    14: 'From High St Westbound to Winthrop St Southbound',
#    15: 'From Winthrop St Southbound to Rt-38 Southbound',
#    16: 'From Rt-38 Southbound to Winthrop St Southbound',
#    17: 'From Winthrop St Southbound to Tesla Ave Westbound',
#    18: 'From Tesla Ave Westbound to Hillsdale Rd Northbound',
#    19: 'Hillsdale Rd Northbound'},
#   'route': 'Route 2',
#   'x_start': 42.4278883,
#   'y_start': -71.09503240000001,
#   'x_end': 42.410395,
#   'y_end': -71.125404,
#   'origin': '42.4278883, -71.09503240000001',
#   'destination': '42.410395, -71.125404',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 9 min',
#   2: ' 3.3 miles'},
#  {0: 'From 75 Quincy St, Medford, MA 02155, USA to 22 Waddell St, Medford, MA 02155, USA',
#   'direction': {0: 'From Osgood St Eastbound to Hillsdale Rd Northbound',
#    1: 'From Hillsdale Rd Northbound to Tesla Ave Eastbound',
#    2: 'From Tesla Ave Eastbound to Winthrop St Northbound',
#    3: 'From Winthrop St Northbound to Rt-38 Northbound',
#    4: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    5: 'From Mystic Valley Pkwy Eastbound to I-93 Northbound',
#    6: 'From I-93 Northbound to Fellsway W Northbound',
#    7: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    8: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    9: 'From Fellsway W Northbound to Elm St Eastbound',
#    10: 'From Elm St Eastbound to Highland Ave Eastbound',
#    11: 'From Highland Ave Eastbound to Waddell St Southbound',
#    12: 'Waddell St Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.410869,
#   'y_start': -71.127038,
#   'x_end': 42.437366,
#   'y_end': -71.08991800000001,
#   'origin': '42.410869, -71.127038',
#   'destination': '42.437366, -71.08991800000001',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 10 min',
#   2: ' 4.9 miles'},
#  {0: 'From 75 Quincy St, Medford, MA 02155, USA to 22 Waddell St, Medford, MA 02155, USA',
#   'direction': {0: 'From Osgood St Westbound to North St Northbound',
#    1: 'From North St Northbound to Woods Ave Westbound',
#    2: 'From Woods Ave Westbound to Alewife Brook Pkwy Northbound',
#    3: 'From Alewife Brook Pkwy Northbound to Mystic Valley Pkwy Northbound',
#    4: 'From Mystic Valley Pkwy Northbound to South St Eastbound',
#    5: 'From South St Eastbound to Main St Northbound',
#    6: 'From Main St Northbound to Riverside Ave Eastbound',
#    7: 'From Riverside Ave Eastbound to City Hall Mall Northbound',
#    8: 'From City Hall Mall Northbound to Salem St Eastbound',
#    9: 'From Salem St Eastbound to Rt-60 Eastbound',
#    10: 'From Rt-60 Eastbound to I-93 Northbound',
#    11: 'From I-93 Northbound to Fellsway W Northbound',
#    12: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    13: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    14: 'From Fellsway W Northbound to Foss St Eastbound',
#    15: 'From Foss St Eastbound to Fulton St Northbound',
#    16: 'From Fulton St Northbound to Park Ave Eastbound',
#    17: 'From Park Ave Eastbound to Waddell St Northbound',
#    18: 'Waddell St Northbound'},
#   'route': 'Route 2',
#   'x_start': 42.410869,
#   'y_start': -71.127038,
#   'x_end': 42.437366,
#   'y_end': -71.08991800000001,
#   'origin': '42.410869, -71.127038',
#   'destination': '42.437366, -71.08991800000001',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 17 min',
#   2: ' 4.2 miles'},
#  {0: 'From 51 Greenleaf Ave, Medford, MA 02155, USA to 289 Elm St, Medford, MA 02155, USA',
#   'direction': {0: 'From Greenleaf Ave Westbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to I-93 Northbound',
#    4: 'From I-93 Northbound to Fellsway W Northbound',
#    5: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    6: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    7: 'From Fellsway W Northbound to Elm St Eastbound',
#    8: 'From Elm St Eastbound to Fulton St Southbound',
#    9: 'Fulton St Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.411885,
#   'y_start': -71.118875,
#   'x_end': 42.441950299999995,
#   'y_end': -71.09466929999999,
#   'origin': '42.411885, -71.118875',
#   'destination': '42.441950299999995, -71.09466929999999',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 8 min',
#   2: ' 4.1 miles'},
#  {0: 'From 51 Greenleaf Ave, Medford, MA 02155, USA to 289 Elm St, Medford, MA 02155, USA',
#   'direction': {0: 'From Greenleaf Ave Westbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to South St Eastbound',
#    4: 'From South St Eastbound to Main St Northbound',
#    5: 'From Main St Northbound to Riverside Ave Eastbound',
#    6: 'From Riverside Ave Eastbound to City Hall Mall Northbound',
#    7: 'From City Hall Mall Northbound to Salem St Eastbound',
#    8: 'From Salem St Eastbound to Rt-60 Eastbound',
#    9: 'From Rt-60 Eastbound to I-93 Northbound',
#    10: 'From I-93 Northbound to Fellsway W Northbound',
#    11: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    12: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    13: 'From Fellsway W Northbound to Elm St Eastbound',
#    14: 'From Elm St Eastbound to Baxter St Eastbound',
#    15: 'From Baxter St Eastbound to Webber St Eastbound',
#    16: 'From Webber St Eastbound to Fulton St Northbound',
#    17: 'Fulton St Northbound'},
#   'route': 'Route 2',
#   'x_start': 42.411885,
#   'y_start': -71.118875,
#   'x_end': 42.441950299999995,
#   'y_end': -71.09466929999999,
#   'origin': '42.411885, -71.118875',
#   'destination': '42.441950299999995, -71.09466929999999',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 8 min',
#   2: ' 3.5 miles'},
#  {0: 'From 676 Fulton St, Medford, MA 02155, USA to Middlesex Ave @ Third St, Medford, MA 02155, USA',
#   'direction': {0: 'From Wason St Eastbound to Fulton St Southbound',
#    1: 'From Fulton St Southbound to Park Ave Eastbound',
#    2: 'From Park Ave Eastbound to Highland Ter Eastbound',
#    3: 'From Highland Ter Eastbound to Highland Ave Eastbound',
#    4: 'From Highland Ave Eastbound to Middlesex Ave Southbound',
#    5: 'Middlesex Ave Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.439910999999995,
#   'y_start': -71.094349,
#   'x_end': 42.409554799999995,
#   'y_end': -71.0798816,
#   'origin': '42.439910999999995, -71.094349',
#   'destination': '42.409554799999995, -71.0798816',
#   'start_zone': 1,
#   'end_zone': 2,
#   1: ' 7 min',
#   2: ' 2.6 miles'},
#  {0: 'From 676 Fulton St, Medford, MA 02155, USA to Middlesex Ave @ Third St, Medford, MA 02155, USA',
#   'direction': {0: 'From Wason St Eastbound to Highland Ave Eastbound',
#    1: 'From Highland Ave Eastbound to Middlesex Ave Southbound',
#    2: 'Middlesex Ave Southbound'},
#   'route': 'Route 2',
#   'x_start': 42.439910999999995,
#   'y_start': -71.094349,
#   'x_end': 42.409554799999995,
#   'y_end': -71.0798816,
#   'origin': '42.439910999999995, -71.094349',
#   'destination': '42.409554799999995, -71.0798816',
#   'start_zone': 1,
#   'end_zone': 2,
#   1: ' 7 min',
#   2: ' 2.7 miles'},
#  {0: 'From 63 Charnwood Rd, Medford, MA 02155, USA to 978 Highland Ave, Medford, MA 02155, USA',
#   'direction': {0: 'From Charnwood Rd Westbound to Winthrop St Northbound',
#    1: 'From Winthrop St Northbound to Rt-38 Northbound',
#    2: 'From Rt-38 Northbound to Mystic Valley Pkwy Eastbound',
#    3: 'From Mystic Valley Pkwy Eastbound to I-93 Northbound',
#    4: 'From I-93 Northbound to Fellsway W Northbound',
#    5: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    6: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    7: 'From Fellsway W Northbound to Elm St Eastbound',
#    8: 'From Elm St Eastbound to Highland Ave Eastbound',
#    9: 'Highland Ave Eastbound'},
#   'route': 'Route 1',
#   'x_start': 42.411164,
#   'y_start': -71.119392,
#   'x_end': 42.442274100000006,
#   'y_end': -71.093848,
#   'origin': '42.411164, -71.119392',
#   'destination': '42.442274100000006, -71.093848',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 8 min',
#   2: ' 4.1 miles'},
#  {0: 'From 63 Charnwood Rd, Medford, MA 02155, USA to 978 Highland Ave, Medford, MA 02155, USA',
#   'direction': {0: 'From Charnwood Rd Eastbound to Benham St Northbound',
#    1: 'From Benham St Northbound to Chester Ave Eastbound',
#    2: 'From Chester Ave Eastbound to Brookings St Northbound',
#    3: 'From Brookings St Northbound to Summer St Westbound',
#    4: 'From Summer St Westbound to Touro Ave Northbound',
#    5: 'From Touro Ave Northbound to South St Eastbound',
#    6: 'From South St Eastbound to Main St Northbound',
#    7: 'From Main St Northbound to Riverside Ave Eastbound',
#    8: 'From Riverside Ave Eastbound to City Hall Mall Northbound',
#    9: 'From City Hall Mall Northbound to Salem St Eastbound',
#    10: 'From Salem St Eastbound to Rt-60 Eastbound',
#    11: 'From Rt-60 Eastbound to I-93 Northbound',
#    12: 'From I-93 Northbound to Fellsway W Northbound',
#    13: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    14: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    15: 'From Fellsway W Northbound to Elm St Eastbound',
#    16: 'From Elm St Eastbound to Highland Ave Eastbound',
#    17: 'Highland Ave Eastbound'},
#   'route': 'Route 2',
#   'x_start': 42.411164,
#   'y_start': -71.119392,
#   'x_end': 42.442274100000006,
#   'y_end': -71.093848,
#   'origin': '42.411164, -71.119392',
#   'destination': '42.442274100000006, -71.093848',
#   'start_zone': 0,
#   'end_zone': 1,
#   1: ' 8 min',
#   2: ' 3.4 miles'},
#  {0: 'From 101 Locust St, Medford, MA 02155, USA to 10 Winthrop St, Medford, MA 02155, USA',
#   'direction': {0: 'From Mystic Valley Pkwy Eastbound to Locust St Northbound',
#    1: 'From Locust St Northbound to Mystic Valley Pkwy Westbound',
#    2: 'From Mystic Valley Pkwy Westbound to Harvard St Westbound',
# ...
#   'origin': '42.4051334, -71.0825552',
#   'destination': '42.4407002, -71.087127',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 8 min',
#   2: ' 3.0 miles'},
#  {},
#  {0: 'From 807-817 MA-28, Medford, MA 02155, USA to 260 Gaston St, Medford, MA 02155, USA',
#   'direction': {0: 'From 4Th St Westbound to Fellsway Northbound',
#    1: 'From Fellsway Northbound to Fellsway E Northbound',
#    2: 'From Fellsway E Northbound to Highland Ave Westbound',
#    3: 'From Highland Ave Westbound to Highland Ter Westbound',
#    4: 'From Highland Ter Westbound to Park Ave Westbound',
#    5: 'From Park Ave Westbound to Benmor St Northbound',
#    6: 'From Benmor St Northbound to Ellsworth St Westbound',
#    7: 'From Ellsworth St Westbound to Gaston St Westbound',
#    8: 'Gaston St Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.411069,
#   'y_start': -71.084974,
#   'x_end': 42.4392748,
#   'y_end': -71.0928331,
#   'origin': '42.411069, -71.084974',
#   'destination': '42.4392748, -71.0928331',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 7 min',
#   2: ' 2.6 miles'},
#  {0: 'From 807-817 MA-28, Medford, MA 02155, USA to 260 Gaston St, Medford, MA 02155, USA',
#   'direction': {0: 'From 4Th St Westbound to Fellsway Northbound',
#    1: 'From Fellsway Northbound to Fellsway E Northbound',
#    2: 'From Fellsway E Northbound to Highland Ave Westbound',
#    3: 'From Highland Ave Westbound to Benmor St Southbound',
#    4: 'From Benmor St Southbound to Ellsworth St Westbound',
#    5: 'From Ellsworth St Westbound to Gaston St Westbound',
#    6: 'Gaston St Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.411069,
#   'y_start': -71.084974,
#   'x_end': 42.4392748,
#   'y_end': -71.0928331,
#   'origin': '42.411069, -71.084974',
#   'destination': '42.4392748, -71.0928331',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 7 min',
#   2: ' 2.7 miles'},
#  {0: 'From 779 Highland Ave, Medford, MA 02155, USA to 10 Winthrop St, Medford, MA 02155, USA',
#   'direction': {0: 'From Victor St Westbound to Highland Ave Eastbound',
#    1: 'From Highland Ave Eastbound to Highland Ter Westbound',
#    2: 'From Highland Ter Westbound to Park Ave Westbound',
#    3: 'From Park Ave Westbound to Fulton St Southbound',
#    4: 'From Fulton St Southbound to Newport Ave Westbound',
#    5: 'From Newport Ave Westbound to Fountain St Southbound',
#    6: 'From Fountain St Southbound to Webster St Westbound',
#    7: 'From Webster St Westbound to Brookside Pkwy Southbound',
#    8: 'From Brookside Pkwy Southbound to Salem St Westbound',
#    9: 'From Salem St Westbound to Rt-60 Westbound',
#    10: 'From Rt-60 Westbound to Main St Westbound',
#    11: 'From Main St Westbound to Summer St Westbound',
#    12: 'From Summer St Westbound to Winthrop St Southbound',
#    13: 'From Winthrop St Southbound to Tesla Ave Westbound',
#    14: 'Tesla Ave Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.437267799999994,
#   'y_start': -71.08748270000001,
#   'x_end': 42.409608,
#   'y_end': -71.123088,
#   'origin': '42.437267799999994, -71.08748270000001',
#   'destination': '42.409608, -71.123088',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 13 min',
#   2: ' 3.6 miles'},
#  {0: 'From 779 Highland Ave, Medford, MA 02155, USA to 10 Winthrop St, Medford, MA 02155, USA',
#   'direction': {0: 'From Victor St Westbound to Highland Ave Westbound',
#    1: 'From Highland Ave Westbound to Elm St Southbound',
#    2: 'From Elm St Southbound to Fellsway W Southbound',
#    3: 'From Fellsway W Southbound to Roosevelt Cir Westbound',
#    4: 'From Roosevelt Cir Westbound to Fellsway W Southbound',
#    5: 'From Fellsway W Southbound to I-93 Southbound',
#    6: 'From I-93 Southbound to Salem St Westbound',
#    7: 'From Salem St Westbound to Rt-60 Westbound',
#    8: 'From Rt-60 Westbound to High St Westbound',
#    9: 'From High St Westbound to Winthrop St Southbound',
#    10: 'From Winthrop St Southbound to Rt-38 Southbound',
#    11: 'From Rt-38 Southbound to Winthrop St Southbound',
#    12: 'From Winthrop St Southbound to Tesla Ave Westbound',
#    13: 'Tesla Ave Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.437267799999994,
#   'y_start': -71.08748270000001,
#   'x_end': 42.409608,
#   'y_end': -71.123088,
#   'origin': '42.437267799999994, -71.08748270000001',
#   'destination': '42.409608, -71.123088',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 10 min',
#   2: ' 4.1 miles'},
#  {0: 'From 831 Fellsway, Medford, MA 02155, USA to 63 McCormack Ave, Medford, MA 02155, USA',
#   'direction': {0: 'From 3Rd St Eastbound to Bradbury Ave Northbound',
#    1: 'From Bradbury Ave Northbound to 2Nd St Westbound',
#    2: 'From 2Nd St Westbound to Fellsway Northbound',
#    3: 'From Fellsway Northbound to Fellsway W Westbound',
#    4: 'From Fellsway W Westbound to Fern Rd Northbound',
#    5: 'From Fern Rd Northbound to Fulton Spring Rd Westbound',
#    6: 'From Fulton Spring Rd Westbound to Fulton St Northbound',
#    7: 'From Fulton St Northbound to Lila Ave Eastbound',
#    8: 'From Lila Ave Eastbound to Mccormack Ave Southbound',
#    9: 'Mccormack Ave Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.4112967,
#   'y_start': -71.08484109999999,
#   'x_end': 42.432548,
#   'y_end': -71.095221,
#   'origin': '42.4112967, -71.08484109999999',
#   'destination': '42.432548, -71.095221',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 8 min',
#   2: ' 2.6 miles'},
#  {0: 'From 831 Fellsway, Medford, MA 02155, USA to 63 McCormack Ave, Medford, MA 02155, USA',
#   'direction': {0: 'From 3Rd St Eastbound to Bradbury Ave Northbound',
#    1: 'From Bradbury Ave Northbound to 2Nd St Westbound',
#    2: 'From 2Nd St Westbound to Fellsway Northbound',
#    3: 'From Fellsway Northbound to Fellsway W Westbound',
#    4: 'From Fellsway W Westbound to Fells Ave Northbound',
#    5: 'From Fells Ave Northbound to Watervale Rd Northbound',
#    6: 'From Watervale Rd Northbound to Lund Rd Eastbound',
#    7: 'From Lund Rd Eastbound to Cedar Rd N Northbound',
#    8: 'From Cedar Rd N Northbound to Tamar Dr Northbound',
#    9: 'From Tamar Dr Northbound to Winslow Ave Westbound',
#    10: 'From Winslow Ave Westbound to Mccormack Ave Southbound',
#    11: 'Mccormack Ave Southbound'},
#   'route': 'Route 2',
#   'x_start': 42.4112967,
#   'y_start': -71.08484109999999,
#   'x_end': 42.432548,
#   'y_end': -71.095221,
#   'origin': '42.4112967, -71.08484109999999',
#   'destination': '42.432548, -71.095221',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 8 min',
#   2: ' 2.5 miles'},
#  {0: 'From 77 2nd St, Medford, MA 02155, USA to 17 Rita Dr, Medford, MA 02155, USA',
#   'direction': {0: 'From 2Nd St Westbound to Fellsway Northbound',
#    1: 'From Fellsway Northbound to Fellsway E Northbound',
#    2: 'From Fellsway E Northbound to Highland Ave Westbound',
#    3: 'From Highland Ave Westbound to Rita Dr Westbound',
#    4: 'Rita Dr Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.411446999999995,
#   'y_start': -71.081398,
#   'x_end': 42.4355449,
#   'y_end': -71.0874971,
#   'origin': '42.411446999999995, -71.081398',
#   'destination': '42.4355449, -71.0874971',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 6 min',
#   2: ' 2.2 miles'},
#  {},
#  {0: 'From 121 Cedar Rd N, Medford, MA 02155, USA to 10 Winthrop St, Medford, MA 02155, USA',
#   'direction': {0: 'From Cedar Rd N Eastbound to Lund Rd Westbound',
#    1: 'From Lund Rd Westbound to Watervale Rd Westbound',
#    2: 'From Watervale Rd Westbound to Oak Rd Westbound',
#    3: 'From Oak Rd Westbound to Hickory Ave Southbound',
#    4: 'From Hickory Ave Southbound to Fells Ave Westbound',
#    5: 'From Fells Ave Westbound to Vista Ave Westbound',
#    6: 'From Vista Ave Westbound to Fulton Spring Rd Westbound',
#    7: 'From Fulton Spring Rd Westbound to Fulton St Southbound',
#    8: 'From Fulton St Southbound to Newport Ave Westbound',
#    9: 'From Newport Ave Westbound to Fountain St Southbound',
#    10: 'From Fountain St Southbound to Webster St Westbound',
#    11: 'From Webster St Westbound to Brookside Pkwy Southbound',
#    12: 'From Brookside Pkwy Southbound to Salem St Westbound',
#    13: 'From Salem St Westbound to Rt-60 Westbound',
#    14: 'From Rt-60 Westbound to Main St Westbound',
#    15: 'From Main St Westbound to Summer St Westbound',
#    16: 'From Summer St Westbound to Winthrop St Southbound',
#    17: 'From Winthrop St Southbound to Tesla Ave Westbound',
#    18: 'Tesla Ave Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.4306115,
#   'y_start': -71.0940926,
#   'x_end': 42.409608,
#   'y_end': -71.123088,
#   'origin': '42.4306115, -71.0940926',
#   'destination': '42.409608, -71.123088',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 11 min',
#   2: ' 3.1 miles'},
#  {0: 'From 121 Cedar Rd N, Medford, MA 02155, USA to 10 Winthrop St, Medford, MA 02155, USA',
#   'direction': {0: 'From Cedar Rd N Eastbound to Lund Rd Westbound',
#    1: 'From Lund Rd Westbound to Watervale Rd Westbound',
#    2: 'From Watervale Rd Westbound to Oak Rd Westbound',
#    3: 'From Oak Rd Westbound to Hickory Ave Southbound',
#    4: 'From Hickory Ave Southbound to Fells Ave Westbound',
#    5: 'From Fells Ave Westbound to Vista Ave Westbound',
#    6: 'From Vista Ave Westbound to Fulton Spring Rd Westbound',
#    7: 'From Fulton Spring Rd Westbound to Rosina St Westbound',
#    8: 'From Rosina St Westbound to Mammola Way Westbound',
#    9: 'From Mammola Way Westbound to Earl Ave Westbound',
#    10: 'From Earl Ave Westbound to Fulton St Eastbound',
#    11: 'From Fulton St Eastbound to Ridgeway Rd Westbound',
#    12: 'From Ridgeway Rd Westbound to Fellsway W Northbound',
#    13: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    14: 'From Roosevelt Cir Northbound to Fellsway W Southbound',
#    15: 'From Fellsway W Southbound to I-93 Southbound',
#    16: 'From I-93 Southbound to Salem St Westbound',
#    17: 'From Salem St Westbound to Rt-60 Westbound',
#    18: 'From Rt-60 Westbound to High St Westbound',
#    19: 'From High St Westbound to Winthrop St Southbound',
#    20: 'From Winthrop St Southbound to Rt-38 Southbound',
#    21: 'From Rt-38 Southbound to Winthrop St Southbound',
#    22: 'From Winthrop St Southbound to Tesla Ave Westbound',
#    23: 'Tesla Ave Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.4306115,
#   'y_start': -71.0940926,
#   'x_end': 42.409608,
#   'y_end': -71.123088,
#   'origin': '42.4306115, -71.0940926',
#   'destination': '42.409608, -71.123088',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 10 min',
#   2: ' 3.6 miles'},
#  {0: 'From 3 6th St, Medford, MA 02155, USA to 43 Winthrop St, Medford, MA 02155, USA',
#   'direction': {0: 'From 6Th St Westbound to Middlesex Ave Southbound',
#    1: 'From Middlesex Ave Southbound to Mystic Valley Pkwy Westbound',
#    2: 'From Mystic Valley Pkwy Westbound to Mystic Ave Northbound',
#    3: 'From Mystic Ave Northbound to Hancock St Westbound',
#    4: 'From Hancock St Westbound to Main St Northbound',
#    5: 'From Main St Northbound to Stearns Ave Westbound',
#    6: 'From Stearns Ave Westbound to College Ave Northbound',
#    7: 'From College Ave Northbound to George St Westbound',
#    8: 'From George St Westbound to Burget Ave Southbound',
#    9: 'From Burget Ave Southbound to Chester Ave Westbound',
#    10: 'From Chester Ave Westbound to Winthrop St Southbound',
#    11: 'Winthrop St Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.4074426,
#   'y_start': -71.0772745,
#   'x_end': 42.410717,
#   'y_end': -71.122337,
#   'origin': '42.4074426, -71.0772745',
#   'destination': '42.410717, -71.122337',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 8 min',
#   2: ' 3.0 miles'},
#  {0: 'From 3 6th St, Medford, MA 02155, USA to 43 Winthrop St, Medford, MA 02155, USA',
#   'direction': {0: 'From 6Th St Westbound to Middlesex Ave Southbound',
#    1: 'From Middlesex Ave Southbound to Mystic Valley Pkwy Westbound',
#    2: 'From Mystic Valley Pkwy Westbound to Harvard St Westbound',
#    3: 'From Harvard St Westbound to Boston Ave Northbound',
#    4: 'From Boston Ave Northbound to College Ave Northbound',
#    5: 'From College Ave Northbound to Boston Ave Northbound',
#    6: 'From Boston Ave Northbound to Winthrop St Southbound',
#    7: 'Winthrop St Southbound'},
#   'route': 'Route 2',
#   'x_start': 42.4074426,
#   'y_start': -71.0772745,
#   'x_end': 42.410717,
#   'y_end': -71.122337,
#   'origin': '42.4074426, -71.0772745',
#   'destination': '42.410717, -71.122337',
#   'start_zone': 2,
#   'end_zone': 0,
#   1: ' 9 min',
#   2: ' 2.9 miles'},
#  {0: 'From 1956 Rivers Edge Dr, Medford, MA 02155, USA to 546 Fulton St, Medford, MA 02155, USA',
#   'direction': {0: 'From Revere Beach Pkwy Westbound to Mystic Valley Pkwy Westbound',
#    1: 'From Mystic Valley Pkwy Westbound to Mystic Ave Eastbound',
#    2: 'From Mystic Ave Eastbound to I-93 Northbound',
#    3: 'From I-93 Northbound to Fellsway W Northbound',
#    4: 'From Fellsway W Northbound to Roosevelt Cir Northbound',
#    5: 'From Roosevelt Cir Northbound to Fellsway W Northbound',
#    6: 'From Fellsway W Northbound to Foss St Eastbound',
#    7: 'From Foss St Eastbound to Fulton St Northbound',
#    8: 'From Fulton St Northbound to Talbot St Westbound',
#    9: 'Talbot St Westbound'},
#   'route': 'Route 1',
#   'x_start': 42.4041002,
#   'y_start': -71.07673929999999,
#   'x_end': 42.4370628,
#   'y_end': -71.0951803,
#   'origin': '42.4041002, -71.07673929999999',
#   'destination': '42.4370628, -71.0951803',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 9 min',
#   2: ' 5.0 miles'},
#  {0: 'From 1956 Rivers Edge Dr, Medford, MA 02155, USA to 546 Fulton St, Medford, MA 02155, USA',
#   'direction': {0: 'From Revere Beach Pkwy Westbound to Fellsway Northbound',
#    1: 'From Fellsway Northbound to Fellsway W Westbound',
#    2: 'From Fellsway W Westbound to Fern Rd Northbound',
#    3: 'From Fern Rd Northbound to Fulton Spring Rd Westbound',
#    4: 'From Fulton Spring Rd Westbound to Fulton St Northbound',
#    5: 'From Fulton St Northbound to Talbot St Westbound',
#    6: 'Talbot St Westbound'},
#   'route': 'Route 2',
#   'x_start': 42.4041002,
#   'y_start': -71.07673929999999,
#   'x_end': 42.4370628,
#   'y_end': -71.0951803,
#   'origin': '42.4041002, -71.07673929999999',
#   'destination': '42.4370628, -71.0951803',
#   'start_zone': 2,
#   'end_zone': 1,
#   1: ' 9 min',
#   2: ' 3.2 miles'},
#  {0: 'From 370 Elm St, Medford, MA 02155, USA to 124 Brookings St, Medford, MA 02155, USA',
#   'direction': {0: 'From Woodland Rd S Southbound to Elm St Southbound',
#    1: 'From Elm St Southbound to Fellsway W Southbound',
#    2: 'From Fellsway W Southbound to Roosevelt Cir Westbound',
#    3: 'From Roosevelt Cir Westbound to Fellsway W Southbound',
#    4: 'From Fellsway W Southbound to I-93 Southbound',
#    5: 'From I-93 Southbound to Salem St Westbound',
#    6: 'From Salem St Westbound to Rt-60 Westbound',
#    7: 'From Rt-60 Westbound to Main St Westbound',
#    8: 'From Main St Westbound to George St Westbound',
#    9: 'From George St Westbound to Burget Ave Southbound',
#    10: 'From Burget Ave Southbound to Chester Ave Westbound',
#    11: 'From Chester Ave Westbound to Brookings St Southbound',
#    12: 'Brookings St Southbound'},
#   'route': 'Route 1',
#   'x_start': 42.444455600000005,
#   'y_start': -71.0946162,
#   'x_end': 42.410699,
#   'y_end': -71.118759,
#   'origin': '42.444455600000005, -71.0946162',
#   'destination': '42.410699, -71.118759',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 8 min',
#   2: ' 3.2 miles'},
#  {0: 'From 370 Elm St, Medford, MA 02155, USA to 124 Brookings St, Medford, MA 02155, USA',
#   'direction': {0: 'From Woodland Rd S Southbound to Elm St Southbound',
#    1: 'From Elm St Southbound to Fellsway W Southbound',
#    2: 'From Fellsway W Southbound to Roosevelt Cir Westbound',
#    3: 'From Roosevelt Cir Westbound to Fellsway W Southbound',
#    4: 'From Fellsway W Southbound to I-93 Southbound',
#    5: 'From I-93 Southbound to Salem St Westbound',
#    6: 'From Salem St Westbound to Rt-60 Westbound',
#    7: 'From Rt-60 Westbound to Main St Westbound',
#    8: 'From Main St Westbound to Summer St Westbound',
#    9: 'From Summer St Westbound to Brookings St Southbound',
#    10: 'Brookings St Southbound'},
#   'route': 'Route 2',
#   'x_start': 42.444455600000005,
#   'y_start': -71.0946162,
#   'x_end': 42.410699,
#   'y_end': -71.118759,
#   'origin': '42.444455600000005, -71.0946162',
#   'destination': '42.410699, -71.118759',
#   'start_zone': 1,
#   'end_zone': 0,
#   1: ' 9 min',
#   2: ' 3.2 miles'}]

# %%
# df=pd.DataFrame.from_dict(cengiz,orient='index').T
# df=df.rename(columns ={0:'from', 1: 'time', 2:'distance'})
# df

# %%
df=pd.DataFrame(cengiz)
df=df.rename(columns={0:'from to where',1:'time',2:'distance'})
df
# Out:
#                                         from to where  \
# 0   From 4110 Mystic Valley Pkwy, Medford, MA 0215...
# 1   From 4110 Mystic Valley Pkwy, Medford, MA 0215...
# 2   From 21 Naomi St, Malden, MA 02148, USA to 616...
# 3                                                 NaN
# 4   From 5 Revere Beach Pkwy, Medford, MA 02155, U...
# 5   From 5 Revere Beach Pkwy, Medford, MA 02155, U...
# 6   From 194 Fells Ave, Medford, MA 02155, USA to ...
# 7                                                 NaN
# 8   From 606 Fulton St, Medford, MA 02155, USA to ...
# 9   From 606 Fulton St, Medford, MA 02155, USA to ...
# 10  From 1 Wilson St, Medford, MA 02155, USA to 76...
# 11  From 1 Wilson St, Medford, MA 02155, USA to 76...
# 12  From 63 Charnwood Rd, Medford, MA 02155, USA t...
# 13  From 63 Charnwood Rd, Medford, MA 02155, USA t...
# 14  From 1956 Rivers Edge Dr, Medford, MA 02155, U...
# 15  From 1956 Rivers Edge Dr, Medford, MA 02155, U...
# 16  From 10 Winthrop St, Medford, MA 02155, USA to...
# 17  From 10 Winthrop St, Medford, MA 02155, USA to...
# 18  From Stop & Shop - New England, 760 Fellsway, ...
# 19  From Stop & Shop - New England, 760 Fellsway, ...
# 20  From 676 Fulton St, Medford, MA 02155, USA to ...
# 21  From 676 Fulton St, Medford, MA 02155, USA to ...
# 22  From 10 Winthrop St, Medford, MA 02155, USA to...
# 23  From 10 Winthrop St, Medford, MA 02155, USA to...
# 24  From 592 Fulton St, Medford, MA 02155, USA to ...
# 25  From 592 Fulton St, Medford, MA 02155, USA to ...
# 26  From 33 Doonan St, Medford, MA 02155, USA to 6...
# 27                                                NaN
# 28  From 75 Quincy St, Medford, MA 02155, USA to 1...
# 29  From 75 Quincy St, Medford, MA 02155, USA to 1...
# ..                                                ...
# 44  From 63 Charnwood Rd, Medford, MA 02155, USA t...
# 45  From 63 Charnwood Rd, Medford, MA 02155, USA t...
# 46  From 101 Locust St, Medford, MA 02155, USA to ...
# 47  From 101 Locust St, Medford, MA 02155, USA to ...
# 48  From 520 Fellsway, Medford, MA 02155, USA to 2...
# 49  From 520 Fellsway, Medford, MA 02155, USA to 2...
# 50  From 40 Tesla Ave, Medford, MA 02155, USA to 4...
# 51  From 40 Tesla Ave, Medford, MA 02155, USA to 4...
# 52  From 7 Sawyer St, Medford, MA 02155, USA to 25...
# 53  From 7 Sawyer St, Medford, MA 02155, USA to 25...
# 54  From 2 Sawyer St, Medford, MA 02155, USA to 43...
# 55  From 2 Sawyer St, Medford, MA 02155, USA to 43...
# 56  From 4110 Mystic Valley Pkwy, Medford, MA 0215...
# 57                                                NaN
# 58  From 807-817 MA-28, Medford, MA 02155, USA to ...
# 59  From 807-817 MA-28, Medford, MA 02155, USA to ...
# 60  From 779 Highland Ave, Medford, MA 02155, USA ...
# 61  From 779 Highland Ave, Medford, MA 02155, USA ...
# 62  From 831 Fellsway, Medford, MA 02155, USA to 6...
# 63  From 831 Fellsway, Medford, MA 02155, USA to 6...
# 64  From 77 2nd St, Medford, MA 02155, USA to 17 R...
# 65                                                NaN
# 66  From 121 Cedar Rd N, Medford, MA 02155, USA to...
# 67  From 121 Cedar Rd N, Medford, MA 02155, USA to...
# 68  From 3 6th St, Medford, MA 02155, USA to 43 Wi...
# 69  From 3 6th St, Medford, MA 02155, USA to 43 Wi...
# 70  From 1956 Rivers Edge Dr, Medford, MA 02155, U...
# 71  From 1956 Rivers Edge Dr, Medford, MA 02155, U...
# 72  From 370 Elm St, Medford, MA 02155, USA to 124...
# 73  From 370 Elm St, Medford, MA 02155, USA to 124...
#
#                                             direction    route    x_start  \
# 0   {0: 'From Mystic Valley Pkwy Westbound to Alew...  Route 1  42.405133
# 1   {0: 'From Mystic Valley Pkwy Westbound to Harv...  Route 2  42.405133
# 2   {0: 'From Naomi St Westbound to Savin St South...  Route 1  42.433370
# 3                                                 NaN      NaN        NaN
# 4   {0: 'From Revere Beach Pkwy Eastbound to Stati...  Route 1  42.404603
# 5   {0: 'From Revere Beach Pkwy Eastbound to Stati...  Route 2  42.404603
# 6   {0: 'From Fells Ave Eastbound to Murray Hill R...  Route 1  42.427888
# 7                                                 NaN      NaN        NaN
# 8   {0: 'From Fulton St Northbound to Gaston St We...  Route 1  42.438188
# 9   {0: 'From Fulton St Southbound to Park Ave Eas...  Route 2  42.438188
# 10  {0: 'From Wilson St Northbound to Mangles St W...  Route 1  42.433405
# 11  {0: 'From Wilson St Northbound to Mangles St W...  Route 2  42.433405
# 12  {0: 'From Charnwood Rd Eastbound to Benham St ...  Route 1  42.411164
# 13  {0: 'From Charnwood Rd Westbound to Winthrop S...  Route 2  42.411164
# 14  {0: 'From Revere Beach Pkwy Westbound to Mysti...  Route 1  42.404100
# 15  {0: 'From Revere Beach Pkwy Westbound to Mysti...  Route 2  42.404100
# 16  {0: 'From Tesla Ave Eastbound to Winthrop St N...  Route 1  42.409608
# 17  {0: 'From Tesla Ave Eastbound to Winthrop St N...  Route 2  42.409608
# 18  {0: 'From Fellsway Southbound to Mystic Valley...  Route 1  42.410107
# 19  {0: 'From Fellsway Southbound to Riverside Ave...  Route 2  42.410107
# 20  {0: 'From Wason St Westbound to Sturges St Wes...  Route 1  42.439911
# 21  {0: 'From Wason St Westbound to Sturges St Wes...  Route 2  42.439911
# 22  {0: 'From Tesla Ave Eastbound to Winthrop St N...  Route 1  42.409608
# 23  {0: 'From Tesla Ave Eastbound to Winthrop St N...  Route 2  42.409608
# 24  {0: 'From Fulton St Westbound to Walsh St West...  Route 1  42.437818
# 25  {0: 'From Fulton St Westbound to Newport Ave W...  Route 2  42.437818
# 26  {0: 'From Doonan St Southbound to Short St Eas...  Route 1  42.434035
# 27                                                NaN      NaN        NaN
# 28  {0: 'From Osgood St Westbound to North St Nort...  Route 1  42.410869
# 29  {0: 'From Osgood St Eastbound to Hillsdale Rd ...  Route 2  42.410869
# ..                                                ...      ...        ...
# 44  {0: 'From Charnwood Rd Westbound to Winthrop S...  Route 1  42.411164
# 45  {0: 'From Charnwood Rd Eastbound to Benham St ...  Route 2  42.411164
# 46  {0: 'From Mystic Valley Pkwy Eastbound to Locu...  Route 1  42.405970
# 47  {0: 'From Mystic Valley Pkwy Eastbound to Locu...  Route 2  42.405970
# 48  {0: 'From Mystic Valley Pkwy Eastbound to Fell...  Route 1  42.404915
# 49  {0: 'From Mystic Valley Pkwy Eastbound to Fell...  Route 2  42.404915
# 50  {0: 'From Tesla Ave Eastbound to Winthrop St N...  Route 1  42.410029
# 51  {0: 'From Tesla Ave Eastbound to Winthrop St N...  Route 2  42.410029
# 52  {0: 'From Sawyer St Southbound to Bowen St Eas...  Route 1  42.433056
# 53  {0: 'From Sawyer St Southbound to Bowen St Eas...  Route 2  42.433056
# 54  {0: 'From Sawyer St Southbound to Bowen St Eas...  Route 1  42.432587
# 55  {0: 'From Sawyer St Southbound to Bowen St Eas...  Route 2  42.432587
# 56  {0: 'From Mystic Valley Pkwy Westbound to Fell...  Route 1  42.405133
# 57                                                NaN      NaN        NaN
# 58  {0: 'From 4Th St Westbound to Fellsway Northbo...  Route 1  42.411069
# 59  {0: 'From 4Th St Westbound to Fellsway Northbo...  Route 2  42.411069
# 60  {0: 'From Victor St Westbound to Highland Ave ...  Route 1  42.437268
# 61  {0: 'From Victor St Westbound to Highland Ave ...  Route 2  42.437268
# 62  {0: 'From 3Rd St Eastbound to Bradbury Ave Nor...  Route 1  42.411297
# 63  {0: 'From 3Rd St Eastbound to Bradbury Ave Nor...  Route 2  42.411297
# 64  {0: 'From 2Nd St Westbound to Fellsway Northbo...  Route 1  42.411447
# 65                                                NaN      NaN        NaN
# 66  {0: 'From Cedar Rd N Eastbound to Lund Rd West...  Route 1  42.430611
# 67  {0: 'From Cedar Rd N Eastbound to Lund Rd West...  Route 2  42.430611
# 68  {0: 'From 6Th St Westbound to Middlesex Ave So...  Route 1  42.407443
# 69  {0: 'From 6Th St Westbound to Middlesex Ave So...  Route 2  42.407443
# 70  {0: 'From Revere Beach Pkwy Westbound to Mysti...  Route 1  42.404100
# 71  {0: 'From Revere Beach Pkwy Westbound to Fells...  Route 2  42.404100
# 72  {0: 'From Woodland Rd S Southbound to Elm St S...  Route 1  42.444456
# 73  {0: 'From Woodland Rd S Southbound to Elm St S...  Route 2  42.444456
#
#       y_start      x_end      y_end                                  origin  \
# 0  -71.082555  42.410869 -71.127038                 42.4051334, -71.0825552
# 1  -71.082555  42.410869 -71.127038                 42.4051334, -71.0825552
# 2  -71.087905  42.405726 -71.082345          42.4333703, -71.08790450000001
# 3         NaN        NaN        NaN                                     NaN
# 4  -71.080997  42.409832 -71.121101         42.404602600000004, -71.0809975
# 5  -71.080997  42.409832 -71.121101         42.404602600000004, -71.0809975
# 6  -71.095032  42.410710 -71.081660          42.4278883, -71.09503240000001
# 7         NaN        NaN        NaN                                     NaN
# 8  -71.093587  42.401760 -71.080298                 42.4381877, -71.0935869
# 9  -71.093587  42.401760 -71.080298                 42.4381877, -71.0935869
# 10 -71.090581  42.410282 -71.125489                  42.4334053, -71.090581
# 11 -71.090581  42.410282 -71.125489                  42.4334053, -71.090581
# 12 -71.119392  42.410299 -71.079618                   42.411164, -71.119392
# 13 -71.119392  42.410299 -71.079618                   42.411164, -71.119392
# 14 -71.076739  42.411164 -71.119392          42.4041002, -71.07673929999999
# 15 -71.076739  42.411164 -71.119392          42.4041002, -71.07673929999999
# 16 -71.123088  42.432587 -71.090548                   42.409608, -71.123088
# 17 -71.123088  42.432587 -71.090548                   42.409608, -71.123088
# 18 -71.084727  42.410029 -71.124367                  42.4101073, -71.084727
# 19 -71.084727  42.410029 -71.124367                  42.4101073, -71.084727
# 20 -71.094349  42.410403 -71.118930          42.439910999999995, -71.094349
# 21 -71.094349  42.410403 -71.118930          42.439910999999995, -71.094349
# 22 -71.123088  42.440762 -71.093069                   42.409608, -71.123088
# 23 -71.123088  42.440762 -71.093069                   42.409608, -71.123088
# 24 -71.093811  42.403987 -71.088942                 42.4378185, -71.0938114
# 25 -71.093811  42.403987 -71.088942                 42.4378185, -71.0938114
# 26 -71.089615  42.408258 -71.083361  42.434034999999994, -71.08961500000001
# 27        NaN        NaN        NaN                                     NaN
# 28 -71.127038  42.405970 -71.094957                   42.410869, -71.127038
# 29 -71.127038  42.405970 -71.094957                   42.410869, -71.127038
# ..        ...        ...        ...                                     ...
# 44 -71.119392  42.442274 -71.093848                   42.411164, -71.119392
# 45 -71.119392  42.442274 -71.093848                   42.411164, -71.119392
# 46 -71.094957  42.409608 -71.123088                 42.4059703, -71.0949567
# 47 -71.094957  42.409608 -71.123088                 42.4059703, -71.0949567
# 48 -71.083567  42.411082 -71.123696                 42.4049152, -71.0835666
# 49 -71.083567  42.411082 -71.123696                 42.4049152, -71.0835666
# 50 -71.124367  42.433796 -71.091316          42.410028999999994, -71.124367
# 51 -71.124367  42.433796 -71.091316          42.410028999999994, -71.124367
# 52 -71.090547  42.411082 -71.123696                 42.4330561, -71.0905475
# 53 -71.090547  42.411082 -71.123696                 42.4330561, -71.0905475
# 54 -71.090548  42.410717 -71.122337                  42.432587, -71.0905484
# 55 -71.090548  42.410717 -71.122337                  42.432587, -71.0905484
# 56 -71.082555  42.440700 -71.087127                 42.4051334, -71.0825552
# 57        NaN        NaN        NaN                                     NaN
# 58 -71.084974  42.439275 -71.092833                   42.411069, -71.084974
# 59 -71.084974  42.439275 -71.092833                   42.411069, -71.084974
# 60 -71.087483  42.409608 -71.123088  42.437267799999994, -71.08748270000001
# 61 -71.087483  42.409608 -71.123088  42.437267799999994, -71.08748270000001
# 62 -71.084841  42.432548 -71.095221          42.4112967, -71.08484109999999
# 63 -71.084841  42.432548 -71.095221          42.4112967, -71.08484109999999
# 64 -71.081398  42.435545 -71.087497          42.411446999999995, -71.081398
# 65        NaN        NaN        NaN                                     NaN
# 66 -71.094093  42.409608 -71.123088                 42.4306115, -71.0940926
# 67 -71.094093  42.409608 -71.123088                 42.4306115, -71.0940926
# 68 -71.077275  42.410717 -71.122337                 42.4074426, -71.0772745
# 69 -71.077275  42.410717 -71.122337                 42.4074426, -71.0772745
# 70 -71.076739  42.437063 -71.095180          42.4041002, -71.07673929999999
# 71 -71.076739  42.437063 -71.095180          42.4041002, -71.07673929999999
# 72 -71.094616  42.410699 -71.118759         42.444455600000005, -71.0946162
# 73 -71.094616  42.410699 -71.118759         42.444455600000005, -71.0946162
#
#                         destination  start_zone  end_zone     time    distance
# 0             42.410869, -71.127038         2.0       0.0   10 min   3.7 miles
# 1             42.410869, -71.127038         2.0       0.0    8 min   2.9 miles
# 2    42.4057258, -71.08234470000001         1.0       2.0    5 min   2.1 miles
# 3                               NaN         NaN       NaN      NaN         NaN
# 4           42.4098316, -71.1211007         2.0       0.0   12 min   2.8 miles
# 5           42.4098316, -71.1211007         2.0       0.0   10 min   3.1 miles
# 6           42.4107101, -71.0816604         1.0       2.0    5 min   2.0 miles
# 7                               NaN         NaN       NaN      NaN         NaN
# 8    42.40176029999999, -71.0802975         1.0       2.0    8 min   4.0 miles
# 9    42.40176029999999, -71.0802975         1.0       2.0    8 min   3.2 miles
# 10   42.410281700000006, -71.125489         1.0       0.0   12 min   3.3 miles
# 11   42.410281700000006, -71.125489         1.0       0.0   10 min   3.9 miles
# 12    42.410299, -71.07961800000001         0.0       2.0    9 min   2.9 miles
# 13    42.410299, -71.07961800000001         0.0       2.0    8 min   3.4 miles
# 14            42.411164, -71.119392         2.0       0.0    7 min   2.8 miles
# 15            42.411164, -71.119392         2.0       0.0    7 min   2.8 miles
# 16           42.432587, -71.0905484         0.0       1.0   10 min   4.5 miles
# 17           42.432587, -71.0905484         0.0       1.0   11 min   3.9 miles
# 18   42.410028999999994, -71.124367         2.0       0.0    9 min   3.3 miles
# 19   42.410028999999994, -71.124367         2.0       0.0   10 min   2.9 miles
# 20             42.410403, -71.11893         1.0       0.0    8 min   3.0 miles
# 21             42.410403, -71.11893         1.0       0.0    8 min   3.0 miles
# 22          42.4407625, -71.0930686         0.0       1.0    9 min   4.3 miles
# 23          42.4407625, -71.0930686         0.0       1.0   10 min   3.7 miles
# 24          42.4039865, -71.0889423         1.0       2.0    7 min   3.6 miles
# 25          42.4039865, -71.0889423         1.0       2.0    8 min   3.4 miles
# 26  42.408258200000006, -71.0833609         1.0       2.0    7 min   2.6 miles
# 27                              NaN         NaN       NaN      NaN         NaN
# 28          42.4059703, -71.0949567         0.0       2.0   12 min   2.8 miles
# 29          42.4059703, -71.0949567         0.0       2.0    6 min   2.6 miles
# ..                              ...         ...       ...      ...         ...
# 44   42.442274100000006, -71.093848         0.0       1.0    8 min   4.1 miles
# 45   42.442274100000006, -71.093848         0.0       1.0    8 min   3.4 miles
# 46            42.409608, -71.123088         2.0       0.0    7 min   2.1 miles
# 47            42.409608, -71.123088         2.0       0.0    6 min   2.2 miles
# 48            42.411082, -71.123696         2.0       0.0    8 min   2.9 miles
# 49            42.411082, -71.123696         2.0       0.0    9 min   2.8 miles
# 50           42.4337965, -71.091316         0.0       1.0    9 min   4.1 miles
# 51           42.4337965, -71.091316         0.0       1.0   10 min   3.5 miles
# 52            42.411082, -71.123696         1.0       0.0   11 min   4.0 miles
# 53            42.411082, -71.123696         1.0       0.0   13 min   3.5 miles
# 54            42.410717, -71.122337         1.0       0.0   12 min   3.5 miles
# 55            42.410717, -71.122337         1.0       0.0   10 min   3.9 miles
# 56           42.4407002, -71.087127         2.0       1.0    8 min   3.0 miles
# 57                              NaN         NaN       NaN      NaN         NaN
# 58          42.4392748, -71.0928331         2.0       1.0    7 min   2.6 miles
# 59          42.4392748, -71.0928331         2.0       1.0    7 min   2.7 miles
# 60            42.409608, -71.123088         1.0       0.0   13 min   3.6 miles
# 61            42.409608, -71.123088         1.0       0.0   10 min   4.1 miles
# 62            42.432548, -71.095221         2.0       1.0    8 min   2.6 miles
# 63            42.432548, -71.095221         2.0       1.0    8 min   2.5 miles
# 64          42.4355449, -71.0874971         2.0       1.0    6 min   2.2 miles
# 65                              NaN         NaN       NaN      NaN         NaN
# 66            42.409608, -71.123088         1.0       0.0   11 min   3.1 miles
# 67            42.409608, -71.123088         1.0       0.0   10 min   3.6 miles
# 68            42.410717, -71.122337         2.0       0.0    8 min   3.0 miles
# 69            42.410717, -71.122337         2.0       0.0    9 min   2.9 miles
# 70          42.4370628, -71.0951803         2.0       1.0    9 min   5.0 miles
# 71          42.4370628, -71.0951803         2.0       1.0    9 min   3.2 miles
# 72            42.410699, -71.118759         1.0       0.0    8 min   3.2 miles
# 73            42.410699, -71.118759         1.0       0.0    9 min   3.2 miles
#
# [74 rows x 13 columns]

# %%
# system allws to scrape maximum 149 times for each individual attempt(loop).
# But you can try for new attempts back to back unlimitedly.

df[df['route']=='Route 1'].shape # represent that how many points you could download for this time!
# Out:
# (37, 13)

# %%
df.shape
# Out:
# (69, 13)

# %%
df.dropna(inplace=True) # null values come from where if there is no option for 'Route 2'
df.shape
# Out:
# (69, 13)

# %%
df.to_csv('./Data/csv_data', index=False)

# %%
problem1=data[3370:3371] #
# id : 1010
# ORIGIN: 42.411885, -71.118875
# DESTINATION: 42.434034999999994, -71.08961500000001

# %%
problem1
# Out:
#        Unnamed: 0  osmid_start    y_start    x_start  start_zone  osmid_end  \
# 10110       10110     66462139 -71.118875  42.411885           0   66431964
#
#            y_end      x_end  end_zone  Time                 origin  \
# 10110 -71.089615  42.434035         1  8:30  42.411885, -71.118875
#
#                                   destination
# 10110  42.434034999999994, -71.08961500000001
